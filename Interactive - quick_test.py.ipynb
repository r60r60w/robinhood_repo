# %% [markdown]
# Restarted Python 3.12.7

# %%
import datetime as dt
import time
import robin_stocks.robinhood as rh
from jh_options import *
from jh_utilities import *
from jh_optionTrader import *
from technical_indicator import *
import yfinance as yf
#import yagmail

import pandas as pd

# %%
login(days=1)
# Out:
# -----Logged in to account belong to: Jiannan Huang -----

# %%
[df1,df2,df3]=tabulate_option_orders_by_symbol('AMD')
# Out:
# Found Additional pages.
# Loading page 2 ...

# %%
df1
# Out:
#                time           strategy effect  side  type         exp  strike  \
# 0  2024-10-30 10:42    open: long call   open   buy  call  2025-06-20   115.0
# 1  2024-10-30 10:42   open: short call   open  sell  call  2024-11-15   167.5
# 2  2024-01-31 09:02  close: short call  close   buy  call  2024-02-02   190.0
# 3  2024-01-31 09:02   close: long call  close  sell  call  2024-02-02   195.0
# 4  2024-01-31 09:02    close: long put  close  sell   put  2024-02-02   152.5
# 5  2024-01-31 09:02   close: short put  close   buy   put  2024-02-02   157.5
# 6  2024-01-30 13:49    open: long call   open   buy  call  2024-02-02   195.0
# 7  2024-01-30 13:49   open: short call   open  sell  call  2024-02-02   190.0
# 8  2024-01-30 13:49     open: long put   open   buy   put  2024-02-02   152.5
# 9  2024-01-30 13:49    open: short put   open  sell   put  2024-02-02   157.5
#
#    quantity  price  premium  running_premium
# 0       1.0  44.50  -4450.0          -3980.0
# 1       1.0   1.10    110.0            470.0
# 2       3.0   0.07    -21.0            360.0
# 3       3.0   0.03      9.0            381.0
# 4       3.0   0.11     33.0            372.0
# 5       3.0   0.46   -138.0            339.0
# 6       3.0   1.87   -561.0            477.0
# 7       3.0   2.59    777.0           1038.0
# 8       3.0   0.85   -255.0            261.0
# 9       3.0   1.72    516.0            516.0

# %%
df2
# Out:
#                time           strategy effect  side  type         exp  strike  \
# 1  2024-10-30 10:42   open: short call   open  sell  call  2024-11-15   167.5
# 2  2024-01-31 09:02  close: short call  close   buy  call  2024-02-02   190.0
# 7  2024-01-30 13:49   open: short call   open  sell  call  2024-02-02   190.0
#
#    quantity  price  premium  running_premium
# 1       1.0   1.10    110.0            470.0
# 2       3.0   0.07    -21.0            360.0
# 7       3.0   2.59    777.0           1038.0

# %%
df2.loc[:, 'running_premium2'] = df2.loc[::-1, 'premium'].copy().cumsum()[::-1]
# Out:
# <ipython-input-6-8541ebb54ede>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[:, 'running_premium2'] = df2.loc[::-1, 'premium'].copy().cumsum()[::-1]

# %%
df2
# Out:
#                time           strategy effect  side  type         exp  strike  \
# 1  2024-10-30 10:42   open: short call   open  sell  call  2024-11-15   167.5
# 2  2024-01-31 09:02  close: short call  close   buy  call  2024-02-02   190.0
# 7  2024-01-30 13:49   open: short call   open  sell  call  2024-02-02   190.0
#
#    quantity  price  premium  running_premium  running_premium2
# 1       1.0   1.10    110.0            470.0             866.0
# 2       3.0   0.07    -21.0            360.0             756.0
# 7       3.0   2.59    777.0           1038.0             777.0

# %%
df.drop(columns='running_premium', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.drop(columns='running_premium', inplace=True)
#
# NameError: name 'df' is not defined

# %%
df2.drop(columns='running_premium', inplace=True)
# Out:
# <ipython-input-9-05438876f15c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns='running_premium', inplace=True)

# %%
df3.drop(columns='running_premium', inplace=True)
# Out:
# <ipython-input-10-82df76b87c6b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop(columns='running_premium', inplace=True)

# %%
df3
# Out:
#                time          strategy effect  side  type         exp  strike  \
# 0  2024-10-30 10:42   open: long call   open   buy  call  2025-06-20   115.0
# 3  2024-01-31 09:02  close: long call  close  sell  call  2024-02-02   195.0
# 6  2024-01-30 13:49   open: long call   open   buy  call  2024-02-02   195.0
#
#    quantity  price  premium
# 0       1.0  44.50  -4450.0
# 3       3.0   0.03      9.0
# 6       3.0   1.87   -561.0

# %%
df1.drop(columns='running_premium', inplace=True)

# %%
df1
# Out:
#                time           strategy effect  side  type         exp  strike  \
# 0  2024-10-30 10:42    open: long call   open   buy  call  2025-06-20   115.0
# 1  2024-10-30 10:42   open: short call   open  sell  call  2024-11-15   167.5
# 2  2024-01-31 09:02  close: short call  close   buy  call  2024-02-02   190.0
# 3  2024-01-31 09:02   close: long call  close  sell  call  2024-02-02   195.0
# 4  2024-01-31 09:02    close: long put  close  sell   put  2024-02-02   152.5
# 5  2024-01-31 09:02   close: short put  close   buy   put  2024-02-02   157.5
# 6  2024-01-30 13:49    open: long call   open   buy  call  2024-02-02   195.0
# 7  2024-01-30 13:49   open: short call   open  sell  call  2024-02-02   190.0
# 8  2024-01-30 13:49     open: long put   open   buy   put  2024-02-02   152.5
# 9  2024-01-30 13:49    open: short put   open  sell   put  2024-02-02   157.5
#
#    quantity  price  premium
# 0       1.0  44.50  -4450.0
# 1       1.0   1.10    110.0
# 2       3.0   0.07    -21.0
# 3       3.0   0.03      9.0
# 4       3.0   0.11     33.0
# 5       3.0   0.46   -138.0
# 6       3.0   1.87   -561.0
# 7       3.0   2.59    777.0
# 8       3.0   0.85   -255.0
# 9       3.0   1.72    516.0

# %% [markdown]
# Restarted Python 3.12.7

# %%
import datetime as dt
import time
import robin_stocks.robinhood as rh
from jh_options import *
from jh_utilities import *
from jh_optionTrader import *
from technical_indicator import *
import yfinance as yf
#import yagmail

import pandas as pd

# %%
login(days=1)
# Out:
# -----Logged in to account belong to: Jiannan Huang -----

# %%
tabulate_option_orders_by_symbol('AMD')
# Out:
# Found Additional pages.
# Loading page 2 ...
# (               time           strategy effect  side  type         exp  strike  \
#  0  2024-10-30 10:42    open: long call   open   buy  call  2025-06-20   115.0
#  1  2024-10-30 10:42   open: short call   open  sell  call  2024-11-15   167.5
#  2  2024-01-31 09:02  close: short call  close   buy  call  2024-02-02   190.0
#  3  2024-01-31 09:02   close: long call  close  sell  call  2024-02-02   195.0
#  4  2024-01-31 09:02    close: long put  close  sell   put  2024-02-02   152.5
#  5  2024-01-31 09:02   close: short put  close   buy   put  2024-02-02   157.5
#  6  2024-01-30 13:49    open: long call   open   buy  call  2024-02-02   195.0
#  7  2024-01-30 13:49   open: short call   open  sell  call  2024-02-02   190.0
#  8  2024-01-30 13:49     open: long put   open   buy   put  2024-02-02   152.5
#  9  2024-01-30 13:49    open: short put   open  sell   put  2024-02-02   157.5
#
#     quantity  price  premium  running_premium
#  0       1.0  44.50  -4450.0          -3980.0
#  1       1.0   1.10    110.0            470.0
#  2       3.0   0.07    -21.0            360.0
#  3       3.0   0.03      9.0            381.0
#  4       3.0   0.11     33.0            372.0
#  5       3.0   0.46   -138.0            339.0
#  6       3.0   1.87   -561.0            477.0
#  7       3.0   2.59    777.0           1038.0
#  8       3.0   0.85   -255.0            261.0
#  9       3.0   1.72    516.0            516.0  ,
#                 time           strategy effect  side  type         exp  strike  \
#  1  2024-10-30 10:42   open: short call   open  sell  call  2024-11-15   167.5
#  2  2024-01-31 09:02  close: short call  close   buy  call  2024-02-02   190.0
#  7  2024-01-30 13:49   open: short call   open  sell  call  2024-02-02   190.0
#
#     quantity  price  premium  running_premium
#  1       1.0   1.10    110.0            866.0
#  2       3.0   0.07    -21.0            756.0
#  7       3.0   2.59    777.0            777.0  ,
#                 time          strategy effect  side  type         exp  strike  \
#  0  2024-10-30 10:42   open: long call   open   buy  call  2025-06-20   115.0
#  3  2024-01-31 09:02  close: long call  close  sell  call  2024-02-02   195.0
#  6  2024-01-30 13:49   open: long call   open   buy  call  2024-02-02   195.0
#
#     quantity  price  premium  running_premium
#  0       1.0  44.50  -4450.0          -5002.0
#  3       3.0   0.03      9.0           -552.0
#  6       3.0   1.87   -561.0           -561.0  )

# %%
[df1,df2,df3] = tabulate_option_orders_by_symbol('AMD')
# Out:
# Found Additional pages.
# Loading page 2 ...

# %%
df1
# Out:
#                time           strategy effect  side  type         exp  strike  \
# 0  2024-10-30 10:42    open: long call   open   buy  call  2025-06-20   115.0
# 1  2024-10-30 10:42   open: short call   open  sell  call  2024-11-15   167.5
# 2  2024-01-31 09:02  close: short call  close   buy  call  2024-02-02   190.0
# 3  2024-01-31 09:02   close: long call  close  sell  call  2024-02-02   195.0
# 4  2024-01-31 09:02    close: long put  close  sell   put  2024-02-02   152.5
# 5  2024-01-31 09:02   close: short put  close   buy   put  2024-02-02   157.5
# 6  2024-01-30 13:49    open: long call   open   buy  call  2024-02-02   195.0
# 7  2024-01-30 13:49   open: short call   open  sell  call  2024-02-02   190.0
# 8  2024-01-30 13:49     open: long put   open   buy   put  2024-02-02   152.5
# 9  2024-01-30 13:49    open: short put   open  sell   put  2024-02-02   157.5
#
#    quantity  price  premium  running_premium
# 0       1.0  44.50  -4450.0          -3980.0
# 1       1.0   1.10    110.0            470.0
# 2       3.0   0.07    -21.0            360.0
# 3       3.0   0.03      9.0            381.0
# 4       3.0   0.11     33.0            372.0
# 5       3.0   0.46   -138.0            339.0
# 6       3.0   1.87   -561.0            477.0
# 7       3.0   2.59    777.0           1038.0
# 8       3.0   0.85   -255.0            261.0
# 9       3.0   1.72    516.0            516.0

# %%
df2
# Out:
#                time           strategy effect  side  type         exp  strike  \
# 1  2024-10-30 10:42   open: short call   open  sell  call  2024-11-15   167.5
# 2  2024-01-31 09:02  close: short call  close   buy  call  2024-02-02   190.0
# 7  2024-01-30 13:49   open: short call   open  sell  call  2024-02-02   190.0
#
#    quantity  price  premium  running_premium
# 1       1.0   1.10    110.0            866.0
# 2       3.0   0.07    -21.0            756.0
# 7       3.0   2.59    777.0            777.0

# %%
df3
# Out:
#                time          strategy effect  side  type         exp  strike  \
# 0  2024-10-30 10:42   open: long call   open   buy  call  2025-06-20   115.0
# 3  2024-01-31 09:02  close: long call  close  sell  call  2024-02-02   195.0
# 6  2024-01-30 13:49   open: long call   open   buy  call  2024-02-02   195.0
#
#    quantity  price  premium  running_premium
# 0       1.0  44.50  -4450.0          -5002.0
# 3       3.0   0.03      9.0           -552.0
# 6       3.0   1.87   -561.0           -561.0

# %%
 optionPositions_rh = rh.options.get_open_option_positions()

# %%
optionPositions_rh
# Out:
# [{'account': 'https://api.robinhood.com/accounts/785982323/',
#   'account_number': '785982323',
#   'average_price': '-19.0000',
#   'chain_id': 'cd15fc05-93fa-4def-9f79-19d4cdd6d660',
#   'chain_symbol': 'INTC',
#   'id': '63c2f79d-004f-40ed-b013-3e30a77254c6',
#   'option': 'https://api.robinhood.com/options/instruments/823471c3-3bce-4df9-ac56-17a77fd5ffe1/',
#   'type': 'short',
#   'pending_buy_quantity': '0.0000',
#   'pending_expired_quantity': '0.0000',
#   'pending_expiration_quantity': '0.0000',
#   'pending_exercise_quantity': '0.0000',
#   'pending_assignment_quantity': '0.0000',
#   'pending_sell_quantity': '0.0000',
#   'quantity': '2.0000',
#   'intraday_quantity': '2.0000',
#   'intraday_average_open_price': '-19.0000',
#   'created_at': '2024-11-01T15:12:11.365996Z',
#   'expiration_date': '2024-11-08',
#   'trade_value_multiplier': '100.0000',
#   'updated_at': '2024-11-01T15:12:24.199984Z',
#   'url': 'https://api.robinhood.com/options/positions/63c2f79d-004f-40ed-b013-3e30a77254c6/',
#   'option_id': '823471c3-3bce-4df9-ac56-17a77fd5ffe1',
#   'clearing_running_quantity': '2.0000',
#   'clearing_cost_basis': '38.0000',
#   'clearing_direction': 'credit',
#   'clearing_intraday_running_quantity': '0',
#   'clearing_intraday_cost_basis': '0',
#   'clearing_intraday_direction': 'credit'},
#  {'account': 'https://api.robinhood.com/accounts/785982323/',
#   'account_number': '785982323',
#   'average_price': '-107.0000',
#   'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'id': '1fe9722c-e988-40e5-8708-3b0199ae9cb1',
#   'option': 'https://api.robinhood.com/options/instruments/250bae7f-db0b-4d28-83d7-4f67b660e53e/',
#   'type': 'short',
#   'pending_buy_quantity': '0.0000',
#   'pending_expired_quantity': '0.0000',
#   'pending_expiration_quantity': '0.0000',
#   'pending_exercise_quantity': '0.0000',
#   'pending_assignment_quantity': '0.0000',
#   'pending_sell_quantity': '0.0000',
#   'quantity': '3.0000',
#   'intraday_quantity': '3.0000',
#   'intraday_average_open_price': '-107.0000',
#   'created_at': '2024-11-01T15:10:12.787761Z',
#   'expiration_date': '2024-11-08',
#   'trade_value_multiplier': '100.0000',
#   'updated_at': '2024-11-01T15:10:27.204554Z',
#   'url': 'https://api.robinhood.com/options/positions/1fe9722c-e988-40e5-8708-3b0199ae9cb1/',
#   'option_id': '250bae7f-db0b-4d28-83d7-4f67b660e53e',
#   'clearing_running_quantity': '3.0000',
#   'clearing_cost_basis': '321.0000',
#   'clearing_direction': 'credit',
#   'clearing_intraday_running_quantity': '0',
#   'clearing_intraday_cost_basis': '0',
#   'clearing_intraday_direction': 'credit'},
#  {'account': 'https://api.robinhood.com/accounts/785982323/',
#   'account_number': '785982323',
#   'average_price': '-1784.0000',
#   'chain_id': '9ee49197-7b3c-46c2-8d83-5d5ad1ed9eaa',
#   'chain_symbol': 'TSLA',
#   'id': '2d80d394-2beb-4f0e-9068-ed48053acdeb',
#   'option': 'https://api.robinhood.com/options/instruments/e80f304a-5cbb-4b48-93a1-8026a3a16941/',
#   'type': 'short',
#   'pending_buy_quantity': '0.0000',
#   'pending_expired_quantity': '0.0000',
#   'pending_expiration_quantity': '0.0000',
#   'pending_exercise_quantity': '0.0000',
#   'pending_assignment_quantity': '0.0000',
#   'pending_sell_quantity': '0.0000',
#   'quantity': '1.0000',
#   'intraday_quantity': '1.0000',
#   'intraday_average_open_price': '-1784.0000',
#   'created_at': '2024-11-01T15:04:37.912731Z',
#   'expiration_date': '2024-11-08',
#   'trade_value_multiplier': '100.0000',
#   'updated_at': '2024-11-01T15:04:52.705604Z',
#   'url': 'https://api.robinhood.com/options/positions/2d80d394-2beb-4f0e-9068-ed48053acdeb/',
#   'option_id': 'e80f304a-5cbb-4b48-93a1-8026a3a16941',
#   'clearing_running_quantity': '1.0000',
#   'clearing_cost_basis': '1784.0000',
#   'clearing_direction': 'credit',
#   'clearing_intraday_running_quantity': '0',
#   'clearing_intraday_cost_basis': '0',
#   'clearing_intraday_direction': 'credit'},
#  {'account': 'https://api.robinhood.com/accounts/785982323/',
#   'account_number': '785982323',
#   'average_price': '-110.0000',
#   'chain_id': 'e66ce029-db96-4572-87a0-b144613c08bf',
#   'chain_symbol': 'AMD',
#   'id': '84c43b70-0380-46f2-9302-0ea5dc1533ec',
#   'option': 'https://api.robinhood.com/options/instruments/ab656f7f-fd73-4d0b-9326-603e679cde4c/',
#   'type': 'short',
#   'pending_buy_quantity': '0.0000',
#   'pending_expired_quantity': '0.0000',
#   'pending_expiration_quantity': '0.0000',
#   'pending_exercise_quantity': '0.0000',
#   'pending_assignment_quantity': '0.0000',
#   'pending_sell_quantity': '0.0000',
#   'quantity': '1.0000',
#   'intraday_quantity': '0.0000',
#   'intraday_average_open_price': '0.0000',
#   'created_at': '2024-10-30T17:41:24.024224Z',
#   'expiration_date': '2024-11-15',
#   'trade_value_multiplier': '100.0000',
#   'updated_at': '2024-10-30T17:42:55.253896Z',
#   'url': 'https://api.robinhood.com/options/positions/84c43b70-0380-46f2-9302-0ea5dc1533ec/',
#   'option_id': 'ab656f7f-fd73-4d0b-9326-603e679cde4c',
#   'clearing_running_quantity': '1.0000',
#   'clearing_cost_basis': '110.0000',
#   'clearing_direction': 'credit',
#   'clearing_intraday_running_quantity': '0',
#   'clearing_intraday_cost_basis': '0',
#   'clearing_intraday_direction': 'credit'},
#  {'account': 'https://api.robinhood.com/accounts/785982323/',
#   'account_number': '785982323',
#   'average_price': '4450.0000',
#   'chain_id': 'e66ce029-db96-4572-87a0-b144613c08bf',
#   'chain_symbol': 'AMD',
#   'id': 'a7e09bbc-141d-46ec-afad-8021933c5621',
#   'option': 'https://api.robinhood.com/options/instruments/676b4619-5ca9-4293-b166-846db308c405/',
#   'type': 'long',
#   'pending_buy_quantity': '0.0000',
#   'pending_expired_quantity': '0.0000',
#   'pending_expiration_quantity': '0.0000',
#   'pending_exercise_quantity': '0.0000',
#   'pending_assignment_quantity': '0.0000',
#   'pending_sell_quantity': '0.0000',
#   'quantity': '1.0000',
#   'intraday_quantity': '0.0000',
#   'intraday_average_open_price': '0.0000',
#   'created_at': '2024-10-30T17:41:23.991106Z',
#   'expiration_date': '2025-06-20',
#   'trade_value_multiplier': '100.0000',
#   'updated_at': '2024-10-30T17:42:55.263472Z',
#   'url': 'https://api.robinhood.com/options/positions/a7e09bbc-141d-46ec-afad-8021933c5621/',
#   'option_id': '676b4619-5ca9-4293-b166-846db308c405',
#   'clearing_running_quantity': '1.0000',
#   'clearing_cost_basis': '4450.0000',
#   'clearing_direction': 'debit',
#   'clearing_intraday_running_quantity': '0',
#   'clearing_intraday_cost_basis': '0',
#   'clearing_intraday_direction': 'debit'},
#  {'account': 'https://api.robinhood.com/accounts/785982323/',
#   'account_number': '785982323',
#   'average_price': '-56.0000',
#   'chain_id': '4b5447d5-a11e-4e96-a505-48913b4703c5',
#   'chain_symbol': 'GOOGL',
#   'id': '1eee26f8-d018-4fb3-8dce-6a43fe553bdd',
#   'option': 'https://api.robinhood.com/options/instruments/18eb093f-8f60-4d4f-80d9-9bbe56dec761/',
#   'type': 'short',
#   'pending_buy_quantity': '0.0000',
#   'pending_expired_quantity': '0.0000',
#   'pending_expiration_quantity': '0.0000',
#   'pending_exercise_quantity': '0.0000',
#   'pending_assignment_quantity': '0.0000',
#   'pending_sell_quantity': '0.0000',
#   'quantity': '1.0000',
#   'intraday_quantity': '0.0000',
#   'intraday_average_open_price': '0.0000',
#   'created_at': '2024-10-28T15:47:37.418022Z',
#   'expiration_date': '2024-11-08',
#   'trade_value_multiplier': '100.0000',
#   'updated_at': '2024-11-01T20:20:24.856473Z',
#   'url': 'https://api.robinhood.com/options/positions/1eee26f8-d018-4fb3-8dce-6a43fe553bdd/',
#   'option_id': '18eb093f-8f60-4d4f-80d9-9bbe56dec761',
#   'clearing_running_quantity': '1.0000',
#   'clearing_cost_basis': '56.0000',
#   'clearing_direction': 'credit',
#   'clearing_intraday_running_quantity': '0',
#   'clearing_intraday_cost_basis': '0',
#   'clearing_intraday_direction': 'credit'},
#  {'account': 'https://api.robinhood.com/accounts/785982323/',
#   'account_number': '785982323',
#   'average_price': '-136.0000',
#   'chain_id': 'fb248609-0fb3-4fc5-a3cf-86c7edb95b42',
#   'chain_symbol': 'TSM',
#   'id': '03de0c69-fea4-41d4-b945-cefaa561c84d',
#   'option': 'https://api.robinhood.com/options/instruments/67ab56e8-273a-488a-a879-12a6cfa5c757/',
#   'type': 'short',
#   'pending_buy_quantity': '0.0000',
#   'pending_expired_quantity': '0.0000',
#   'pending_expiration_quantity': '0.0000',
#   'pending_exercise_quantity': '0.0000',
#   'pending_assignment_quantity': '0.0000',
#   'pending_sell_quantity': '0.0000',
#   'quantity': '1.0000',
#   'intraday_quantity': '0.0000',
#   'intraday_average_open_price': '0.0000',
#   'created_at': '2024-10-28T15:44:52.436541Z',
#   'expiration_date': '2024-11-08',
#   'trade_value_multiplier': '100.0000',
#   'updated_at': '2024-10-28T15:44:52.864614Z',
#   'url': 'https://api.robinhood.com/options/positions/03de0c69-fea4-41d4-b945-cefaa561c84d/',
#   'option_id': '67ab56e8-273a-488a-a879-12a6cfa5c757',
#   'clearing_running_quantity': '1.0000',
#   'clearing_cost_basis': '136.0000',
#   'clearing_direction': 'credit',
#   'clearing_intraday_running_quantity': '0',
#   'clearing_intraday_cost_basis': '0',
#   'clearing_intraday_direction': 'credit'},
#  {'account': 'https://api.robinhood.com/accounts/785982323/',
#   'account_number': '785982323',
#   'average_price': '7185.0000',
#   'chain_id': 'fb248609-0fb3-4fc5-a3cf-86c7edb95b42',
#   'chain_symbol': 'TSM',
#   'id': 'b3624f6d-5940-409f-8f03-1464233fefdd',
#   'option': 'https://api.robinhood.com/options/instruments/5ac45dd9-75fd-4d13-9acb-3e5e5f2fafdc/',
#   'type': 'long',
#   'pending_buy_quantity': '0.0000',
#   'pending_expired_quantity': '0.0000',
#   'pending_expiration_quantity': '0.0000',
#   'pending_exercise_quantity': '0.0000',
#   'pending_assignment_quantity': '0.0000',
#   'pending_sell_quantity': '0.0000',
#   'quantity': '1.0000',
#   'intraday_quantity': '0.0000',
#   'intraday_average_open_price': '0.0000',
#   'created_at': '2024-10-17T16:56:35.533915Z',
#   'expiration_date': '2025-06-20',
#   'trade_value_multiplier': '100.0000',
#   'updated_at': '2024-10-17T16:56:36.373733Z',
#   'url': 'https://api.robinhood.com/options/positions/b3624f6d-5940-409f-8f03-1464233fefdd/',
#   'option_id': '5ac45dd9-75fd-4d13-9acb-3e5e5f2fafdc',
#   'clearing_running_quantity': '1.0000',
#   'clearing_cost_basis': '7185.0000',
#   'clearing_direction': 'debit',
#   'clearing_intraday_running_quantity': '0',
#   'clearing_intraday_cost_basis': '0',
#   'clearing_intraday_direction': 'debit'},
#  {'account': 'https://api.robinhood.com/accounts/785982323/',
#   'account_number': '785982323',
#   'average_price': '600.0000',
#   'chain_id': 'cd15fc05-93fa-4def-9f79-19d4cdd6d660',
#   'chain_symbol': 'INTC',
#   'id': '4ace23b1-e3c4-494c-8793-77d90542dca4',
#   'option': 'https://api.robinhood.com/options/instruments/c9a9be8b-f69e-4b06-be2e-706dd46ca4dc/',
#   'type': 'long',
#   'pending_buy_quantity': '0.0000',
#   'pending_expired_quantity': '0.0000',
#   'pending_expiration_quantity': '0.0000',
#   'pending_exercise_quantity': '0.0000',
#   'pending_assignment_quantity': '0.0000',
#   'pending_sell_quantity': '0.0000',
#   'quantity': '2.0000',
#   'intraday_quantity': '0.0000',
#   'intraday_average_open_price': '0.0000',
#   'created_at': '2024-10-15T14:56:44.236172Z',
#   'expiration_date': '2025-08-15',
#   'trade_value_multiplier': '100.0000',
#   'updated_at': '2024-10-15T14:56:44.702695Z',
#   'url': 'https://api.robinhood.com/options/positions/4ace23b1-e3c4-494c-8793-77d90542dca4/',
#   'option_id': 'c9a9be8b-f69e-4b06-be2e-706dd46ca4dc',
#   'clearing_running_quantity': '2.0000',
#   'clearing_cost_basis': '1200.0000',
#   'clearing_direction': 'debit',
#   'clearing_intraday_running_quantity': '0',
#   'clearing_intraday_cost_basis': '0',
#   'clearing_intraday_direction': 'debit'},
#  {'account': 'https://api.robinhood.com/accounts/785982323/',
#   'account_number': '785982323',
#   'average_price': '5100.0000',
#   'chain_id': '9ee49197-7b3c-46c2-8d83-5d5ad1ed9eaa',
#   'chain_symbol': 'TSLA',
#   'id': 'c057db62-0ac8-45c5-a00e-79243287d1c2',
#   'option': 'https://api.robinhood.com/options/instruments/e033bc30-5ae7-4825-8bc7-b40b198c1928/',
#   'type': 'long',
#   'pending_buy_quantity': '0.0000',
#   'pending_expired_quantity': '0.0000',
#   'pending_expiration_quantity': '0.0000',
#   'pending_exercise_quantity': '0.0000',
#   'pending_assignment_quantity': '0.0000',
#   'pending_sell_quantity': '0.0000',
#   'quantity': '1.0000',
#   'intraday_quantity': '0.0000',
#   'intraday_average_open_price': '0.0000',
#   'created_at': '2024-10-11T15:24:42.315540Z',
#   'expiration_date': '2025-06-20',
#   'trade_value_multiplier': '100.0000',
#   'updated_at': '2024-10-11T15:24:42.774829Z',
#   'url': 'https://api.robinhood.com/options/positions/c057db62-0ac8-45c5-a00e-79243287d1c2/',
#   'option_id': 'e033bc30-5ae7-4825-8bc7-b40b198c1928',
#   'clearing_running_quantity': '1.0000',
#   'clearing_cost_basis': '5100.0000',
#   'clearing_direction': 'debit',
#   'clearing_intraday_running_quantity': '0',
#   'clearing_intraday_cost_basis': '0',
#   'clearing_intraday_direction': 'debit'},
#  {'account': 'https://api.robinhood.com/accounts/785982323/',
#   'account_number': '785982323',
#   'average_price': '3987.0000',
#   'chain_id': '4b5447d5-a11e-4e96-a505-48913b4703c5',
#   'chain_symbol': 'GOOGL',
#   'id': '284ac067-2594-4ac2-8b91-9c10a0eecb46',
#   'option': 'https://api.robinhood.com/options/instruments/8efb7928-f97c-4e5b-beed-965e4799f70f/',
#   'type': 'long',
#   'pending_buy_quantity': '0.0000',
#   'pending_expired_quantity': '0.0000',
#   'pending_expiration_quantity': '0.0000',
#   'pending_exercise_quantity': '0.0000',
#   'pending_assignment_quantity': '0.0000',
#   'pending_sell_quantity': '0.0000',
#   'quantity': '1.0000',
#   'intraday_quantity': '0.0000',
#   'intraday_average_open_price': '0.0000',
#   'created_at': '2024-10-10T17:00:28.686709Z',
#   'expiration_date': '2025-06-20',
#   'trade_value_multiplier': '100.0000',
#   'updated_at': '2024-10-10T17:02:21.711378Z',
#   'url': 'https://api.robinhood.com/options/positions/284ac067-2594-4ac2-8b91-9c10a0eecb46/',
#   'option_id': '8efb7928-f97c-4e5b-beed-965e4799f70f',
#   'clearing_running_quantity': '1.0000',
#   'clearing_cost_basis': '3987.0000',
#   'clearing_direction': 'debit',
#   'clearing_intraday_running_quantity': '0',
#   'clearing_intraday_cost_basis': '0',
#   'clearing_intraday_direction': 'debit'},
#  {'account': 'https://api.robinhood.com/accounts/785982323/',
#   'account_number': '785982323',
#   'average_price': '4030.0000',
#   'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'id': 'b4b5810e-342e-41bf-9d24-192b0a3a46ae',
#   'option': 'https://api.robinhood.com/options/instruments/cea4d669-8eb1-4420-9cad-eefb1c925821/',
#   'type': 'long',
#   'pending_buy_quantity': '0.0000',
#   'pending_expired_quantity': '0.0000',
#   'pending_expiration_quantity': '0.0000',
#   'pending_exercise_quantity': '0.0000',
#   'pending_assignment_quantity': '0.0000',
#   'pending_sell_quantity': '0.0000',
#   'quantity': '3.0000',
#   'intraday_quantity': '0.0000',
#   'intraday_average_open_price': '0.0000',
#   'created_at': '2024-06-26T16:22:32.994182Z',
#   'expiration_date': '2025-06-20',
#   'trade_value_multiplier': '100.0000',
#   'updated_at': '2024-06-26T16:23:04.654480Z',
#   'url': 'https://api.robinhood.com/options/positions/b4b5810e-342e-41bf-9d24-192b0a3a46ae/',
#   'option_id': 'cea4d669-8eb1-4420-9cad-eefb1c925821',
#   'clearing_running_quantity': '3.0000',
#   'clearing_cost_basis': '12090.0000',
#   'clearing_direction': 'debit',
#   'clearing_intraday_running_quantity': '0',
#   'clearing_intraday_cost_basis': '0',
#   'clearing_intraday_direction': 'debit'}]

# %%
optionPositions_rh[0]['option_id']
# Out:
# '823471c3-3bce-4df9-ac56-17a77fd5ffe1'

# %%
rh.options.get_option_instrument_data_by_id(optionPositions_rh[0]['option_id'])
# Out:
# {'chain_id': 'cd15fc05-93fa-4def-9f79-19d4cdd6d660',
#  'chain_symbol': 'INTC',
#  'created_at': '2024-09-26T01:08:09.758663Z',
#  'expiration_date': '2024-11-08',
#  'id': '823471c3-3bce-4df9-ac56-17a77fd5ffe1',
#  'issue_date': '2024-09-26',
#  'min_ticks': {'above_tick': '0.05',
#   'below_tick': '0.01',
#   'cutoff_price': '3.00'},
#  'rhs_tradability': 'tradable',
#  'state': 'active',
#  'strike_price': '25.0000',
#  'tradability': 'tradable',
#  'type': 'call',
#  'updated_at': '2024-09-26T01:08:09.758668Z',
#  'url': 'https://api.robinhood.com/options/instruments/823471c3-3bce-4df9-ac56-17a77fd5ffe1/',
#  'sellout_datetime': '2024-11-08T20:30:00+00:00',
#  'long_strategy_code': '823471c3-3bce-4df9-ac56-17a77fd5ffe1_L1',
#  'short_strategy_code': '823471c3-3bce-4df9-ac56-17a77fd5ffe1_S1'}

# %%
all_orders_rh = rh.orders.get_all_option_orders()
# Out:
# Found Additional pages.
# Loading page 2 ...

# %%
all_orders_rh = rh.orders.get_all_option_orders(info='AMD')
# Out:
# Found Additional pages.
# Loading page 2 ...
# Error: The keyword "AMD" is not a key in the dictionary.

# %%
all_orders_rh = rh.orders.get_all_option_orders(info='id')
# Out:
# Found Additional pages.
# Loading page 2 ...

# %%
all_orders_rh
# Out:
# ['6724f03a-3692-43b4-9a2c-e4da90a0ce03',
#  '6724efcb-cdf1-48cd-ba6e-e3afa60f99ed',
#  '6724ef54-a69c-45d6-b198-ff39dfa4adfc',
#  '6724ee05-c99e-46cf-a8cd-c3f237779641',
#  '6722701e-dd10-4e21-9fe8-2696e77501bc',
#  '67226fc3-83da-4bcd-9ac9-d95034eaa76d',
#  '671fb219-b3d5-4f0e-b5ab-296dc547edd1',
#  '671fb174-1dbc-4f64-bc8c-cc69c6dfdf82',
#  '671bc603-d2b9-494d-92a5-9afdc2d11c44',
#  '671bb31d-7f3e-41ee-8841-9e3786a3adb7',
#  '671a7c61-2f64-4ce1-b0fa-e671b032b902',
#  '671935c7-f2e5-43a1-b2da-02bf30b056ca',
#  '6717bd8c-0177-46ae-8f4b-2a420e104717',
#  '671142b0-8e55-4a8c-8a27-030164e92e3e',
#  '671141c3-4a90-4928-b24d-e859beef21ba',
#  '6711242e-2e05-4228-9d7b-da770a97ceae',
#  '67112373-6f62-4367-a468-b1fe0da7fda1',
#  '670ec598-ae06-46ba-8764-ee939e8d11c9',
#  '670e82ac-c4cf-4074-b0a5-ccfea8fb965b',
#  '67094d2c-e10c-42fa-8a52-5dccdf315ffc',
#  '6709433a-8adb-4c5c-b880-92af778c39b3',
#  '67081826-5420-4182-a46b-9bf4b87cee8c',
#  '6708082c-bf4a-4117-b102-bda0573f50e6',
#  '6706c226-4d88-43aa-9611-28f29f57aeaa',
#  '6704249a-1901-4310-9e93-376095cc7a5e',
#  '6703f616-44a8-4488-a19d-560de33e3c77',
#  '6703f3f9-18a2-45f7-a5c2-1e419ed6f122',
#  '670019ef-8033-4504-ba96-2018592095f0',
#  '670019bc-fdb5-4723-8d32-c5654b08f5c4',
#  '66fd5d1e-072d-4997-8a48-dd7fff323451',
#  '66fb8c07-cb03-4a3f-8bd6-193eeeab0c16',
#  '66fb8bf2-0704-4726-90fb-8430cae60ce3',
#  '66fb8bc5-1ee1-4df0-8dd5-f59bc8ceb97f',
#  '66f43c2a-e3b6-4f03-8489-e47949eb4459',
#  '66ed8d15-ab64-4ba8-9f4c-4897e40aa006',
#  '66ed8cc8-3222-4901-a321-4896a271b76f',
#  '66e8e3f6-2867-484c-b255-63333943ea49',
#  '66e88cd3-fefe-4554-9fb8-0d61334d5d3e',
#  '66e88c6a-7a73-43fb-ac73-eb30e69ebcc4',
#  '66e30696-840c-43bf-af79-58db9a04ed3a',
#  '66e1b86f-3a13-4ab5-b49c-20f3e621c7a8',
#  '66e1a3e0-99b1-4390-9a52-8e3abe46e98f',
#  '66d8a202-aeb2-4da0-a18d-ceab57681ab6',
#  '66d8a1c3-113f-4f56-a5d8-8f73933386bc',
#  '66d8965d-797a-49f6-8f77-41f2e71a6ec4',
#  '66d22085-c5f8-4d99-87a5-4a5e4d4cc7c3',
#  '66d2205c-2ee0-40b9-88b1-0942c161c88d',
#  '66cdef00-3b4b-44a9-9a88-59d7a9f75a49',
#  '66cdeeeb-c84a-4b89-a18c-8d6a7258c2e9',
#  '66c8e591-59e8-4066-8f82-1a9fbadc5657',
#  '66c754a1-e840-42cd-aa29-b7c4acdf13e3',
#  '66c5f6a3-b164-4e73-b8a0-5c90a3610ac3',
#  '66c4a5eb-8201-42e1-97e3-8b319c20d646',
#  '66c3a25c-463b-406d-84af-1958a491af0e',
#  '66bfa74e-17bf-434d-ad8b-5edfdd9ae312',
#  '66bfa700-a83e-486f-830d-fb75435fd8ea',
#  '66bfa677-3f37-43c0-95ff-f7b81af6fbab',
#  '66bfa656-7266-4424-a6dd-0e2493549aff',
#  '66be1401-0739-4cf9-8672-a2d8709b890b',
#  '66ba3ded-3cab-49ab-abb3-813c1849db5d',
#  '66ba376b-dddd-4edd-bac7-df9cd7c21eac',
#  '66b62a1b-16e3-4298-a03b-0bc02604d29e',
#  '66b250be-eeae-425a-a3c2-a4e42b6ba8a7',
#  '66b25011-dbf5-4bb3-9fe1-95206c4b3ff7',
#  '66b24fc0-2714-437c-b9f7-0f4085335023',
#  '66b0f4a6-d40b-4e76-bd6a-07d1931baa32',
#  '66b0e705-d32e-488e-9f09-411c1328cd8c',
#  '66a7abe3-5ea2-4b7e-9e6c-83785ab25d41',
#  '66a7abbb-b133-4a22-aedb-ead1235373dd',
#  '66a7ab93-f8dd-4d22-bc46-7b033cf5cd9b',
#  '66a7ab29-ff67-47d8-b7c5-db56c5f31f90',
#  '66a7aabc-86ed-4399-aaec-b311e026d75b',
#  '66a7aa5a-472f-4c19-b7b2-93d3713fa9ec',
#  '66a26f25-a4f9-421b-ae12-dae55ec6db45',
#  '669fc84a-bb22-4eec-b2e6-b25c95d531d6',
#  '669ac0e8-3603-4d21-9f65-c3074d7b8042',
#  '669a76e5-f253-4712-9e4c-00a440b67b08',
#  '66993654-e32b-4f52-a6ba-e30fdfe25e53',
#  '66981066-67e0-45b5-b83b-e82ea30bec16',
#  '6697e9e7-d059-4b90-b31a-f105ca5068bb',
#  '6697dc66-f1f3-4c37-8b64-4b019f0b1f4b',
#  '6696900c-10ae-4a3c-83f2-67beed9abf24',
#  '669689cd-97d5-4cb1-8393-d922f9d2cd6b',
#  '669688f3-7715-48ca-8d73-a2be5c295c9d',
#  '669688c8-77cb-41ba-a655-478faf3bda49',
#  '66902d9b-88fc-4a3a-9ddb-94d3264477be',
#  '66902d4c-f3f2-4ff5-8922-ddfcabb18341',
#  '66902d20-c6cc-475f-b884-4f852d2fc83b',
#  '668ff731-8431-4d38-8a96-a80fba6a485b',
#  '668eed24-e086-42cd-bf0f-f4070e6fc725',
#  '668ebda0-272f-4f5f-9251-1e216fc8c9f2',
#  '668ebc9f-7e5a-4947-aecd-17a5d483b992',
#  '66882204-46ff-4f8f-8ca4-30b7137fcb5b',
#  '66880441-dec0-4fb0-be8d-968e2f80176d',
#  '66880288-2736-46d1-bbdd-598518ce7158',
#  '66880219-7357-4e28-b57f-d3e69d49d179',
#  '668801c5-ab5d-4a73-af8a-0858d0fae59d',
#  '667eccb2-7543-41c7-8c83-711a38bb5265',
#  '667ecc6d-8937-4d62-a34b-2c4267ee0e4d',
#  '667d956c-36bb-4ae9-aa99-5eacfe780624',
#  '667d8621-dbe9-4cf1-a27b-b39b7eb48f85',
#  '667d859a-d76e-4134-b5f9-130e92081a35',
#  '667c4068-9424-4ae9-8375-62d6d7251cbe',
#  '667c4048-1aad-46a6-9c54-365fc5a6c0a6',
#  '667c3dcc-29b4-4a1d-96d5-3bfcb15682db',
#  '667af4e6-b2af-416e-93de-f01b850d84fa',
#  '667ae73b-f6ad-43d5-9ae8-9c5713daca22',
#  '667ae5a6-d20b-47ab-9171-0155790a4949',
#  '667ad5b9-29d3-4f54-bd5f-e9d99ed14f1c',
#  '667994de-ee63-4934-b529-dc94b20c6356',
#  '66798ef7-e60f-4327-a93d-69ada1f3ccde',
#  '66798e06-9eb1-4143-8abe-8a1715bb402d',
#  '66798871-f174-491d-a016-d6a3a1aebeaf',
#  '66798854-1262-474a-a9ae-2e4341f51cac',
#  '66759ee5-9358-4b1a-ae6a-32bb8131fa70',
#  '66759ecd-04d9-4ee1-9dfe-9d085733d3de',
#  '66748997-305d-4216-b169-fe0f0abc53e2',
#  '6674894d-4262-41e3-b9ae-c03088b4d011',
#  '6674755f-8d45-4e8c-b4d2-4a0162b7fa55',
#  '66746d83-4d07-4740-a48d-487a11a6ea66',
#  '66744b1c-236b-4c8d-9e3f-e8d8372d3e7f',
#  '66744ac6-67c7-4be0-928a-c4776c5f2e5d',
#  '66744ab5-65b5-4bc9-a7f1-be2b7970d1d5',
#  '6671b2cd-6fc3-4734-aee8-f41ffc22a948',
#  '6671b254-9f0c-4e0f-82ac-e2b4b07623d9',
#  '66709100-c69b-4942-8f66-54f8273d53e8',
#  '667090ab-deff-453b-8752-daba38539b5d',
#  '666c5953-d966-454b-9ec2-7043456f1e73',
#  '666b2d91-0036-483f-8e78-5e7068634862',
#  '666b05e8-3305-49d4-a85c-1e2629857ead',
#  '666b0549-fe99-4250-a5a0-315436dc9c74',
#  '666b04e6-c420-4a8e-9617-9ef31c5bd106',
#  '6669cb35-3c90-4d51-a1de-0512a04ad482',
#  '6669c00a-8858-43e6-9086-a9aa5a9f84b1',
#  '6669be72-0a71-49e2-be8c-6b2331d39b45',
#  '66688488-df50-4f05-9b9a-c8eded6b2307',
#  '66688431-db00-47e7-b45a-53fd41980cdf',
#  '666869c7-0a65-4f4d-a316-0b611e86a0f3',
#  '66631a7f-f2b1-462f-b148-83ce80fefaf2',
#  '6661ee1b-d834-405e-a854-17bed8c02ed0',
#  '6661ed0d-012c-4c53-a086-035143705cd6',
#  '6661e7e0-03d0-462c-94bd-af97f4cb1f80',
#  '6661e7c6-5e96-4157-8902-125071964145',
#  '66608a28-91a0-49f2-aeee-a54766aa4ec7',
#  '665f3d90-2406-42bc-963b-3ecfda9dc4b7',
#  '665f3d63-29ac-463a-a227-ca6c87700eac',
#  '665f3d40-0fe7-4a50-94e9-6d188eb3a940',
#  '665de5c6-f606-4b13-8b7b-e2ccc2eb6d95',
#  '665d1bef-f26b-4ec4-b9c9-5b8d0791f5b5',
#  '665bd6b2-1a05-427b-9067-26c82b4083b0',
#  '665bd65f-5930-47cd-94f2-6effcf4b8f13',
#  '665bd61c-c34d-4878-ae23-c2f9b453368f',
#  '665bd5c8-7ba9-44fa-a447-d8bce80c2e6f',
#  '665bd585-0bcb-4726-803f-f165776c4aa9',
#  '665bd534-94b6-4e4c-bd5f-70c34624f5a9',
#  '665bd371-691e-4481-816e-509849209cb3',
#  '665bd31e-0c3c-4148-a594-aa21e77d3d0c',
#  '665bd2d9-36d9-46d6-bbc3-9f836f20297a',
#  '665bd287-d95f-43f7-933e-be0d852be352',
#  '665bd188-7bad-46e2-837c-ba96dba9ce8d',
#  '665bd07b-fcf7-4ed0-94ef-0e0c5ff7a514',
#  '66576e0d-1cae-4947-8060-338295bd6f76',
#  '66576cff-e539-49e9-b15b-d27f96186915',
#  '665737db-9bb1-497e-b7e1-109396aa9d5a',
#  '6655eec5-2fbc-4719-bfe4-bb74a51a8aae',
#  '66526d2f-f2b1-43ba-8bc9-233a6b952b5b',
#  '66516410-72dc-4df6-99f2-5da7b3f551a9',
#  '6650b568-067c-455b-a3cd-8150575fb9d2',
#  '6650b237-4d57-4184-9fe8-51ec99c6821f',
#  '6650b217-0a45-4581-841c-65f9bd94b3c4',
#  '664f7561-b770-4347-9875-dcedd77cffca',
#  '664f5d83-f047-40a2-977c-2b1547b5070e',
#  '664786e3-5a20-47bd-8f16-4e856369b469',
#  '66455823-de4a-48e7-a557-edc6754aea57',
#  '664556ff-9928-4877-8b98-ae51da82d6c8',
#  '66450d51-bbaa-422d-85fa-fb7577404978',
#  '66450bf8-40a8-4fb7-bf3f-ad6c3efe849e',
#  '6644ea0e-c346-4e0b-ab07-67d25a382890',
#  '6644e9a0-c22f-4356-a707-15aa33231ce1',
#  '6643be94-51a0-40fe-b2fc-b8022069c463',
#  '663e7409-7aae-498b-b413-3c72aeb8f90f',
#  '663e736f-ad25-4a98-b7eb-c792ebd50653',
#  '663e7317-67da-4fa0-80b8-582abf193ddf',
#  '663cf6fa-a8c9-45c4-b44a-a6cf6f54b880',
#  '663bafff-eb65-4d17-b53b-d4e00ed72a8b',
#  '663b9865-0b40-4951-8785-678135ac777a',
#  '663a57f4-e8f9-4e30-a902-fe2239ecd9ab',
#  '66353f0b-645c-4371-831f-ab07ae456406',
#  '66353aff-a316-49e0-a8eb-f54e26e1c503',
#  '66350d3f-8fd7-4bf8-a9b6-7b2fbc508393',
#  '66350355-c0cd-4b67-a11e-765c257b9532',
#  '6634fef0-5136-4424-8a2d-9c79fa06511d',
#  '6634fe0d-a514-4651-95e3-92b04724c2ea',
#  '662fba3e-27e4-46cc-be8a-04fb2f97352f',
#  '662c02dd-d052-48fd-a410-f9f87a823b9e',
#  '662bc5ed-d215-417c-b39a-80cbb5509694',
#  '662bc4b4-59da-4f27-bf7a-3d934cd7db16',
#  '662bc49d-b343-49e1-ae3c-6b81b454a098',
#  '662a8286-b063-4fd3-8d8b-92b2de0d3bbf',
#  '66269631-d7d2-4ae3-b5fe-3040b049de3c',
#  '66240297-4b1d-43e5-af6a-984e9134f0d4',
#  '66240280-f0ee-442c-8d07-7bffeff9d66d',
#  '6624019b-df1e-4937-a81f-2870686cf0af',
#  '66240183-0e5f-463e-8dc1-c60849320b02',
#  '6623ff3b-dae4-4bef-9952-f2f5528a0b80',
#  '6623ff1f-3a95-41d3-9ff9-f07e57f68901',
#  '6623fe31-d3e1-4882-b9d7-c57617295891',
#  '6623fdc9-2189-46e5-904c-e57ea736b39b',
#  '6623f5f9-cc25-415d-8e1d-3bba9d5d57f9',
#  '6623f585-67a4-497b-9cff-40492a457960',
#  '6623f320-8dc5-408e-80b6-9d58baaec654',
#  '66228b89-f9b9-4fd6-ac24-9d1c29bbcead',
#  '66228866-39c4-49d3-aeb3-773ea9e63562',
#  '662287d0-06fd-41b1-a1fa-ebee1a61c150',
#  '662146c2-991c-4ac9-b41b-46dccdc1e5bd',
#  '6621464a-2c8b-46d0-84de-831b8d5e370f',
#  '66214523-3288-4ea7-a23d-0d5bf0334bca',
#  '661d52a5-1b6b-47f1-a32b-ffa59e87d2f8',
#  '661d51eb-68d3-48cb-b08c-e0a4f5d0a076',
#  '661986fb-c167-43ab-bf37-d77050097fee',
#  '66181c15-227b-47cb-805d-e9cd20f87946',
#  '661808da-0091-4a7d-8155-b68054957a2c',
#  '6616a609-a3f5-4b2d-be4b-19ea8a3afbd2',
#  '66154e4d-6eee-4d95-8482-dabef4f08b86',
#  '66154e0b-2673-4bfb-bfb0-b410da84d1eb',
#  '661420ba-6cb1-4d3a-a8fa-7687e3c41c24',
#  '66141fb8-dced-48cc-91f4-2c35bc5c3ad1',
#  '66141fb4-d96f-4159-b865-3cfd0546b142',
#  '66141fa3-1ee4-41ad-a4e9-f722a95dd23d',
#  '66141c90-35df-477c-a821-d5e0ed5c6892',
#  '6614109e-1b1d-4f1e-982a-7cea01bab404',
#  '6613fedc-4f23-4d99-8221-a3dd77c3d116',
#  '6613fe8b-aa18-460d-95d2-07ecf2d6de0d',
#  '6611ca72-e15c-40b6-ae7a-c2b5374607d7',
#  '6611c979-3651-4c77-a397-7a308fabbf9e',
#  '660ed48c-fed1-4e8d-bc2d-924dd312ebe3',
#  '660ed427-c7e2-4a9d-bec9-f228595f36db',
#  '660a40c1-4d4e-4017-acbc-ca577aa1e08d',
#  '660a40ad-4f96-43ba-bb5a-2fc4aa5a6b21',
#  '660a3feb-1fa4-486c-aedf-8def6d16ee6e',
#  '660a3fd9-fa5c-4167-b8e2-d638e5ad07bf',
#  '660a3b30-df7b-43e0-a432-693eb3873e46',
#  '660a3b1d-a638-4017-98ba-24b4cfdd4ae6',
#  '660a3a7b-66bb-440e-bec4-4563c74687bb',
#  '660a3a6a-5628-42da-ae53-616b78de900b',
#  '660a3a58-7989-460c-b880-56cacc0dd909',
#  '660a390e-08de-410c-9a44-8dfe5030b9f8',
#  '660a38fd-3213-4f4f-90c9-472c747c61e7',
#  '660a38eb-939f-40df-91f1-9e9538c8bd96',
#  '660a38c1-f981-42c7-a2a7-69a5880c1a13',
#  '66025095-59e0-4810-bdef-7fc4781100d5',
#  '66024fd1-55d0-437b-af84-b65aba4f99b1',
#  '66018efc-462b-4168-acb3-e1925c89d3ac',
#  '66010faa-9cdf-4b34-9e8f-819ef6eaa6d9',
#  '66010f00-f269-4675-bf1e-be9d650ff729',
#  '66010eb8-32d1-46fb-8d82-945774da948f',
#  '66010d76-9896-41c2-9cf4-b3d8b180cbf7',
#  '66010949-23e6-45ad-a39f-c96c894c19d4',
#  '6600f853-d9a3-46b9-8c43-65c08fb82543',
#  '65fe2f8c-3af7-47a0-84ac-db891f743018',
#  '65fe1298-fd99-44d9-a121-e855fedda1d9',
#  '65fda270-9bce-4dbd-94fb-c96570fc6084',
#  '65fd2734-5546-47b5-bcf3-2d403e4c59f5',
#  '65fd264e-d6a7-46f7-8ce0-904212d2a2e5',
#  '65fd2170-b84f-4970-a36a-9a5f1b6cf403',
#  '65fa2e3c-1f07-45ce-8ec8-f5fe08adb1aa',
#  '65f9c81d-07cc-43c3-b465-64b90c25d6e8',
#  '65f777cb-ef5f-4c8d-bf93-0cd7583c920e',
#  '65f73966-9bed-49e1-b412-0a00ebb15965',
#  '65eb7370-f129-41e8-a903-ffaf1eb483cd',
#  '65ea574d-ceb3-4a9c-ae46-925645bb916c',
#  '65ea054d-94df-47d4-a6a6-3c7be773ceef',
#  '65e7468e-f97d-4ebd-8760-2389469bd9bf',
#  '65e7465b-3d0d-441e-8310-8c75f5ff7bb6',
#  '65e60858-4665-4470-b50d-40757170683f',
#  '65e5e93a-3ffb-46de-8e6e-e0e5a438a87f',
#  '65e218ad-ac4d-40e9-8d65-84caff3cff58',
#  '65e1f4ee-00f7-4615-8ef6-4091e618ee1e',
#  '65e1f464-5683-4a73-a260-de820fc4fd4b',
#  '65df5e23-cfc6-41b5-bdd4-f928a2aa9662',
#  '65dcb9de-04a8-478e-8927-e1f036376f3e',
#  '65dcb986-15fc-4894-a5fd-f665bc6d34af',
#  '65dcb914-4d59-4c13-9bba-c66db863ff4d',
#  '65dcb8aa-f9d6-4901-abe1-d17788c3a571',
#  '65d90509-3fdc-4a4f-a626-9f087f300a12',
#  '65d7603d-8a4b-44fd-be26-e847a977ec90',
#  '65d75e4e-640b-4b0c-87f4-3d9eb3d5e892',
#  '65d63df7-f14e-41b7-ac92-2b021d494de3',
#  '65d627ce-a84b-4c29-83ed-5dd210a85de7',
#  '65d502de-8df5-4746-923e-42f635cd9883',
#  '65d4f102-2c33-4080-af0f-8866bd09eeac',
#  '65d4f0c5-0dbb-46c0-a2ce-f319340f9ac3',
#  '65d4ce3b-db8e-4c10-9129-d45bbeb6efdd',
#  '65d4c885-a27e-4919-a307-de57b9c9d8fb',
#  '65cf84ea-82ea-43a8-8192-a37609987fe4',
#  '65ce6f3b-adbe-4f70-a941-85f28832ed3b',
#  '65ce6ca4-02f0-4007-8c7f-67801ad2daa3',
#  '65ce6406-9b9e-4895-bd94-b506e3a878d1',
#  '65ce373a-4bbc-4b17-8a68-12a862dc27cd',
#  '65cbc524-d53b-43cf-843f-4faad4d5390a',
#  '65cbc4d1-7117-403a-a823-b0ffef13263b',
#  '65ca41d3-1326-4d01-8547-b177f121bea7',
#  '65c659c0-e062-4aa8-bb2c-4cf5be1d4d85',
#  '65c540ba-cc14-486f-8fd6-4b057f0d114e',
#  '65c4ffce-aeb5-455c-a8ef-748257036a26',
#  '65c3ea37-f237-4a21-b91e-487644f23b0e',
#  '65c3e98a-89d3-448a-89be-03ee8655bb70',
#  '65c3c839-ad57-4d1f-8caf-375179999d6e',
#  '65c3c79d-1236-49cb-b9a5-4cef2626d96c',
#  '65c3c757-dd6c-4f7f-b1fc-cb297a599353',
#  '65c3a79f-e4c2-4fdd-83cb-780b54a34390',
#  '65c295fc-771b-464b-8634-739dfbc7f489',
#  '65c273ee-709d-4037-b743-2a1695f85679',
#  '65c25a77-f303-40e4-b630-1a55781883fc',
#  '65c10412-60ae-48b4-b0ec-13c11fb6ad5e',
#  '65bd5156-d050-49c4-8393-ce6f770dab7e',
#  '65bd123b-1e9f-47be-b67d-89eea61ab4cf',
#  '65bd1175-0a9c-4f54-b0c2-b9d77fd6e23d',
#  '65bd0e12-858e-4160-8d06-3dd7689dabbb',
#  '65bd0cfe-f8bf-4250-8802-d212a03e1b3c',
#  '65bd0c63-0c14-4d27-9e03-9bf64c41ce49',
#  '65bd0bc2-998b-4dd8-b500-fc04d05db626',
#  '65bbc6aa-31f6-4503-a4bd-77b0ff51da44',
#  '65bbc53b-9bba-497d-b264-7c707b3030bf',
#  '65bbc4b8-1194-49d4-9ca3-666ecc5e67e4',
#  '65ba6efa-ae3a-4c91-9920-8791f0546807',
#  '65b960dc-28cb-47c4-8cb3-c44e0a0f2f0a',
#  '65b95cec-0ea3-47b0-bb9c-dfbacfb7614a',
#  '65b95226-53fa-437f-9c32-974747501e66',
#  '65b94cf7-6d7f-4380-906e-0f7152b80bcd',
#  '65b918a3-1ae7-41b6-90e2-45babe8ee5ff',
#  '65b91785-057a-4102-a342-5816068bff7d',
#  '65b91765-49da-4778-a4e7-5a1de71a0a96',
#  '65b80e93-ac18-482a-9faa-12744a2d2ebc',
#  '65b7ce97-cdd6-4f77-abec-ef3196041fc3',
#  '65b3d96c-2953-497b-80ab-f88e662c05ae',
#  '65b3d805-caad-4280-bc6a-598c87a0a7f6',
#  '65b3d4b3-6695-4653-85b2-92ed82175e37',
#  '65b2b32d-aa58-4a4d-86f8-50921c8a628b',
#  '65b29505-c15e-4361-9ebc-a4007d706387',
#  '65b1369b-e708-4627-aa69-2472f4a0f3b0',
#  '65a99cdf-3cfc-47cd-8f4d-9d938d689d47',
#  '65a1a5f7-9fa6-4f60-905a-eca7832c8118',
#  '65a1a5b8-e523-4873-815c-3cac1d3bb804',
#  '6585cccc-039b-4d6b-a0a3-2e904adf6e1d',
#  'a5e6388b-1dd7-4399-9ac9-9f95c20f0163',
#  '969882d3-be69-4665-8865-63709e246c27',
#  'f23a45d4-c134-456d-a2ea-31e38124fa4f',
#  '93fe2dbc-602d-4197-8c44-73f2e041ca1b',
#  '5d1d44bd-a62a-47e3-8d49-77418bc3ea4f']

# %% [markdown]
# Restarted Python 3.12.7

# %%
import datetime as dt
import time
import robin_stocks.robinhood as rh
from jh_options import *
from jh_utilities import *
from jh_optionTrader import *
from technical_indicator import *
import yfinance as yf
#import yagmail

import pandas as pd

# %%
login(days=1)
# Out:
# -----Logged in to account belong to: Jiannan Huang -----

# %%
optionPositions = OptionPosition()
positions = optionPositions.get_all_positions()
cost = optionPositions.calculate_option_cost(positions[6])
# Out:
# Found Additional pages.
# Loading page 2 ...
# Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data

# %%
import datetime as dt
import time
import robin_stocks.robinhood as rh
from jh_options import *
from jh_utilities import *
from jh_optionTrader import *
from technical_indicator import *
import yfinance as yf
#import yagmail

import pandas as pd

# %%
login(days=1)
# Out:
# -----Logged in to account belong to: Jiannan Huang -----

# %%
optionPositions = OptionPosition()
# Out:
# Found Additional pages.
# Loading page 2 ...
# Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data

# %% [markdown]
# Restarted Python 3.12.7

# %%
import datetime as dt
import time
import robin_stocks.robinhood as rh
from jh_options import *
from jh_utilities import *
from jh_optionTrader import *
from technical_indicator import *
import yfinance as yf
#import yagmail

import pandas as pd

# %%
login(days=1)
# Out:
# -----Logged in to account belong to: Jiannan Huang -----

# %%
optionPositions = OptionPosition()
# Out:
# Found Additional pages.
# Loading page 2 ...
# Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data

# %% [markdown]
# Restarted Python 3.12.7

# %%
import datetime as dt
import time
import robin_stocks.robinhood as rh
from jh_options import *
from jh_utilities import *
from jh_optionTrader import *
from technical_indicator import *
import yfinance as yf
#import yagmail

import pandas as pd

# %%
login(days=1)
# Out:
# -----Logged in to account belong to: Jiannan Huang -----

# %%
optionPositions = OptionPosition()
# Out:
# Found Additional pages.
# Loading page 2 ...
# updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data

# %%
optionPositions.positions_df
# Out:
#     symbol   type         exp  strike   delta   theta  quantity  \
# 11    NVDA   long  2025-06-20   100.0  0.8344 -0.0417       3.0
# 9     TSLA   long  2025-06-20   200.0  0.7655 -0.0864       1.0
# 7      TSM   long  2025-06-20   145.0  0.8619 -0.0441       1.0
# 10   GOOGL   long  2025-06-20   130.0  0.8983 -0.0298       1.0
# 4      AMD   long  2025-06-20   115.0  0.7902 -0.0419       1.0
# 8     INTC   long  2025-08-15    20.0  0.7166 -0.0070       2.0
# 5    GOOGL  short  2024-11-08   190.0  0.0044 -0.0124       1.0
# 0     INTC  short  2024-11-08    25.0  0.0828 -0.0326       2.0
# 3      AMD  short  2024-11-15   167.5  0.0371 -0.0502       1.0
# 6      TSM  short  2024-11-08   212.5  0.0423 -0.1329       1.0
# 1     NVDA  short  2024-11-08   144.0  0.1637 -0.2456       3.0
# 2     TSLA  short  2024-11-08   237.5  0.6241 -1.0063       1.0
# sum    NaN    NaN         NaN     NaN     NaN     NaN       NaN
#
#      current price  total value  total cost  total return
# 11           45.52      13656.0     12090.0        1566.0
# 9            66.85       6685.0      5100.0        1585.0
# 7            55.77       5577.0      4034.0        1543.0
# 10           45.12       4512.0      2849.0        1663.0
# 4            36.33       3633.0      4450.0        -817.0
# 8             5.33       1066.0      1200.0        -134.0
# 5            -0.01         -1.0       -56.0          55.0
# 0            -0.06        -12.0       -66.0          54.0
# 3            -0.18        -18.0      -110.0          92.0
# 6            -0.19        -19.0      -136.0         117.0
# 1            -0.64       -192.0      -432.0         240.0
# 2           -10.93      -1093.0      -401.0        -692.0
# sum            NaN      33794.0     28522.0        5272.0

# %%
optionPositions.update()
# Out:
# Found Additional pages.
# Loading page 2 ...
# updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data

# %%
optionPositions.positions_df
# Out:
#     symbol   type         exp  strike   delta   theta  quantity  \
# 11    NVDA   long  2025-06-20   100.0  0.8508 -0.0404       3.0
# 9     TSLA   long  2025-06-20   200.0  0.7912 -0.0841       1.0
# 7      TSM   long  2025-06-20   145.0  0.8788 -0.0420       1.0
# 10   GOOGL   long  2025-06-20   130.0  0.8899 -0.0318       1.0
# 4      AMD   long  2025-06-20   115.0  0.8022 -0.0400       1.0
# 8     INTC   long  2025-08-15    20.0  0.7344 -0.0080       2.0
# 5    GOOGL  short  2024-11-08   190.0  0.0045 -0.0170       1.0
# 3      AMD  short  2024-11-15   167.5  0.0304 -0.0435       1.0
# 0     INTC  short  2024-11-08    25.0  0.1407 -0.0575       2.0
# 6      TSM  short  2024-11-08   212.5  0.0621 -0.2256       1.0
# 1     NVDA  short  2024-11-08   144.0  0.2908 -0.4286       3.0
# 2     TSLA  short  2024-11-08   237.5  0.7537 -1.2967       1.0
# sum    NaN    NaN         NaN     NaN     NaN     NaN       NaN
#
#      current price  total value  total cost  total return
# 11           48.58      14574.0     12090.0        2484.0
# 9            72.97       7297.0      5100.0        2197.0
# 7            59.08       5908.0      4034.0        1874.0
# 10           46.02       4602.0      2849.0        1753.0
# 4            36.50       3650.0      4450.0        -800.0
# 8             6.50       1300.0      1200.0         100.0
# 5            -0.01         -1.0       -56.0          55.0
# 3            -0.14        -14.0      -110.0          96.0
# 0            -0.10        -20.0       -66.0          46.0
# 6            -0.27        -27.0      -136.0         109.0
# 1            -1.23       -369.0      -432.0          63.0
# 2           -17.55      -1755.0      -401.0       -1354.0
# sum            NaN      35145.0     28522.0        6623.0

# %%
optionPositions.update()
optionPositions.positions_df
# Out:
# Found Additional pages.
# Loading page 2 ...
# updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data
#     symbol   type         exp  strike   delta   theta  quantity  \
# 11    NVDA   long  2025-06-20   100.0  0.8810 -0.0358       3.0
# 9     TSLA   long  2025-06-20   200.0  0.8664 -0.0788       1.0
# 7      TSM   long  2025-06-20   145.0  0.8599 -0.0464       1.0
# 10   GOOGL   long  2025-06-20   130.0  0.9253 -0.0276       1.0
# 4      AMD   long  2025-06-20   115.0  0.8126 -0.0415       1.0
# 8     INTC   long  2025-08-15    20.0  0.7882 -0.0072       2.0
# 5    GOOGL  short  2024-11-08   190.0  0.0061 -0.0270       1.0
# 6      TSM  short  2024-11-08   212.5  0.0192 -0.1235       1.0
# 3      AMD  short  2024-11-15   167.5  0.0314 -0.0451       1.0
# 0     INTC  short  2024-11-08    25.0  0.5328 -0.1480       2.0
# 1     NVDA  short  2024-11-08   144.0  0.6365 -0.5812       3.0
# 2     TSLA  short  2024-11-08   237.5  0.9948 -0.1327       1.0
# sum    NaN    NaN         NaN     NaN     NaN     NaN       NaN
#
#      current price  total value  total cost  total return
# 11           52.60      15780.0     12090.0        3690.0
# 9           104.53      10453.0      5100.0        5353.0
# 7            57.98       5798.0      4034.0        1764.0
# 10           51.67       5167.0      2849.0        2318.0
# 4            39.85       3985.0      4450.0        -465.0
# 8             7.42       1484.0      1200.0         284.0
# 5            -0.01         -1.0       -56.0          55.0
# 6            -0.06         -6.0      -136.0         130.0
# 3            -0.13        -13.0      -110.0          97.0
# 0            -0.52       -104.0       -66.0         -38.0
# 1            -2.92       -876.0      -432.0        -444.0
# 2           -51.08      -5108.0      -401.0       -4707.0
# sum            NaN      36559.0     28522.0        8037.0

# %%
optionPositions.update()
optionPositions.positions_df
# Out:
# Found Additional pages.
# Loading page 2 ...
# updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data
#     symbol   type         exp  strike   delta   theta  quantity  \
# 11    NVDA   long  2025-06-20   100.0  0.8796 -0.0378       3.0
# 9     TSLA   long  2025-06-20   200.0  0.9004 -0.0765       1.0
# 7      TSM   long  2025-06-20   145.0  0.8982 -0.0394       1.0
# 10   GOOGL   long  2025-06-20   130.0  0.9357 -0.0262       1.0
# 6      AMD   long  2025-06-20   115.0  0.8319 -0.0394       1.0
# 8     INTC   long  2025-08-15    20.0  0.8207 -0.0069       2.0
# 5      AMD  short  2024-11-15   167.5  0.0324 -0.0498       1.0
# 1    GOOGL  short  2024-11-15   187.5  0.0588 -0.0441       1.0
# 0      TSM  short  2024-11-15   212.5  0.1397 -0.1603       1.0
# 3     INTC  short  2024-11-15    25.0  0.8000 -0.0328       2.0
# 4     NVDA  short  2024-11-15   146.0  0.6086 -0.1913       3.0
# 2     TSLA  short  2024-11-15   237.5  0.9865 -0.1348       1.0
# sum    NaN    NaN         NaN     NaN     NaN     NaN       NaN
#
#      current price  total value  total cost  total return
# 11           54.90      16470.0     12090.0        4380.0
# 9           131.68      13168.0      5100.0        8068.0
# 7            63.30       6330.0      4034.0        2296.0
# 10           53.77       5377.0      2849.0        2528.0
# 6            41.70       4170.0      4450.0        -280.0
# 8             8.22       1644.0      1200.0         444.0
# 5            -0.12        -12.0      -110.0          98.0
# 1            -0.12        -12.0       -68.0          56.0
# 0            -0.69        -69.0      -222.0         153.0
# 3            -1.40       -280.0      -100.0        -180.0
# 4            -3.58      -1074.0      -504.0        -570.0
# 2           -80.65      -8065.0      -429.0       -7636.0
# sum            NaN      37647.0     28290.0        9357.0

# %%
optionPositions.update()
optionPositions.positions_df
# Out:
# Found Additional pages.
# Loading page 2 ...
# updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data updating option...
# Loading Market Data
#     symbol   type         exp  strike   delta   theta  quantity  \
# 12    NVDA   long  2025-06-20   100.0  0.8785 -0.0381       3.0
# 10    TSLA   long  2025-06-20   200.0  0.8998 -0.0769       1.0
# 8      TSM   long  2025-06-20   145.0  0.8972 -0.0398       1.0
# 11   GOOGL   long  2025-06-20   130.0  0.9365 -0.0261       1.0
# 7      AMD   long  2025-06-20   115.0  0.8327 -0.0392       1.0
# 9     INTC   long  2025-08-15    20.0  0.8192 -0.0070       2.0
# 2    GOOGL  short  2024-11-15   187.5  0.0591 -0.0441       1.0
# 6      AMD  short  2024-11-15   167.5  0.0324 -0.0498       1.0
# 1      TSM  short  2024-11-15   212.5  0.1415 -0.1615       1.0
# 0     NVDA  short  2024-11-15   152.5  0.2452 -0.1503       1.0
# 4     INTC  short  2024-11-15    25.0  0.7998 -0.0340       2.0
# 5     NVDA  short  2024-11-15   146.0  0.6094 -0.1908       3.0
# 3     TSLA  short  2024-11-15   237.5  0.9893 -0.1120       1.0
# sum    NaN    NaN         NaN     NaN     NaN     NaN       NaN
#
#      current price  total value  total cost  total return
# 12           54.95      16485.0     12090.0        4395.0
# 10          131.68      13168.0      5100.0        8068.0
# 8            63.45       6345.0      4034.0        2311.0
# 11           53.80       5380.0      2849.0        2531.0
# 7            41.67       4167.0      4450.0        -283.0
# 9             8.30       1660.0      1200.0         460.0
# 2            -0.12        -12.0       -68.0          56.0
# 6            -0.12        -12.0      -110.0          98.0
# 1            -0.71        -71.0      -222.0         151.0
# 0            -0.94        -94.0       -93.0          -1.0
# 4            -1.45       -290.0      -100.0        -190.0
# 5            -3.58      -1074.0      -504.0        -570.0
# 3           -80.67      -8067.0      -429.0       -7638.0
# sum            NaN      37585.0     28197.0        9388.0

# %%
index=1
print(f'[{index+1}] ')
# Out:
# [2]

# %%
index=1
print(f'[{index+1}]')
print(f'[{index+1}]')
# Out:
# [2]
# [2]

# %%
index=1
print(f'[{index+1}]', end='')
print(f'[{index+1}]')
# Out:
# [2][2]

# %% [markdown]
# Restarted Python 3.12.7

# %%
import datetime as dt
import time
import robin_stocks.robinhood as rh
from jh_options import *
from jh_utilities import *
from jh_optionTrader import *
from technical_indicator import *
import yfinance as yf
#import yagmail

import pandas as pd

# %%
login(days=1)
# Out:
# -----Logged in to account belong to: Jiannan Huang -----

# %%
optionPositions = OptionPosition()
positions = optionPositions.get_all_positions()
cost = optionPositions.calculate_option_cost(positions[6])
# Out:
# Found Additional pages.
# [2024-11-08 11:48:29,819] {jh_options.py:33} INFO - updating option...
# Loading page 2 ...
# Loading Market Data
# [2024-11-08 11:48:30,897] {jh_options.py:33} INFO - updating option...
# Loading Market Data /
# [2024-11-08 11:48:31,731] {jh_options.py:33} INFO - updating option...
# Loading Market Data -
# [2024-11-08 11:48:32,424] {jh_options.py:33} INFO - updating option...
# Loading Market Data \
# [2024-11-08 11:48:33,128] {jh_options.py:33} INFO - updating option...
# Loading Market Data |
# [2024-11-08 11:48:33,824] {jh_options.py:33} INFO - updating option...
# Loading Market Data
# [2024-11-08 11:48:34,631] {jh_options.py:33} INFO - updating option...
# Loading Market Data -
# [2024-11-08 11:48:35,305] {jh_options.py:33} INFO - updating option...
# Loading Market Data \
# [2024-11-08 11:48:35,967] {jh_options.py:33} INFO - updating option...
# Loading Market Data |
# [2024-11-08 11:48:36,679] {jh_options.py:33} INFO - updating option...
# Loading Market Data
# [2024-11-08 11:48:37,512] {jh_options.py:33} INFO - updating option...
# Loading Market Data
# [2024-11-08 11:48:38,246] {jh_options.py:33} INFO - updating option...
# Loading Market Data \
# [2024-11-08 11:48:38,975] {jh_options.py:33} INFO - updating option...
# Loading Market Data

# %%
optionPositions = OptionPosition()
positions = optionPositions.get_all_positions()
cost = optionPositions.calculate_option_cost(positions[6])
# Out:
# Found Additional pages.
# [2024-11-08 11:48:43,839] {jh_options.py:33} INFO - updating option...
# Loading page 2 ...
# Loading Market Data
# [2024-11-08 11:48:44,630] {jh_options.py:33} INFO - updating option...
# Loading Market Data -
# [2024-11-08 11:48:45,447] {jh_options.py:33} INFO - updating option...
# Loading Market Data
# [2024-11-08 11:48:46,281] {jh_options.py:33} INFO - updating option...
# Loading Market Data |
# [2024-11-08 11:48:46,981] {jh_options.py:33} INFO - updating option...
# Loading Market Data /
# [2024-11-08 11:48:47,658] {jh_options.py:33} INFO - updating option...
# Loading Market Data
# [2024-11-08 11:48:48,471] {jh_options.py:33} INFO - updating option...
# Loading Market Data \
# [2024-11-08 11:48:49,174] {jh_options.py:33} INFO - updating option...
# Loading Market Data |
# [2024-11-08 11:48:49,880] {jh_options.py:33} INFO - updating option...
# Loading Market Data /
# [2024-11-08 11:48:50,554] {jh_options.py:33} INFO - updating option...
# Loading Market Data -
# [2024-11-08 11:48:51,212] {jh_options.py:33} INFO - updating option...
# Loading Market Data \
# [2024-11-08 11:48:51,916] {jh_options.py:33} INFO - updating option...
# Loading Market Data |
# [2024-11-08 11:48:52,631] {jh_options.py:33} INFO - updating option...
# Loading Market Data

# %%
optionPositions.positions_df
# Out:
#     symbol  type   side         exp  strike   delta   theta  quantity  \
# 12    NVDA  call   long  2025-06-20   100.0  0.8780 -0.0380       3.0
# 10    TSLA  call   long  2025-06-20   200.0  0.9059 -0.0747       1.0
# 8      TSM  call   long  2025-06-20   145.0  0.8995 -0.0396       1.0
# 11   GOOGL  call   long  2025-06-20   130.0  0.9347 -0.0265       1.0
# 7      AMD  call   long  2025-06-20   115.0  0.8330 -0.0393       1.0
# 9     INTC  call   long  2025-08-15    20.0  0.8159 -0.0068       2.0
# 6      AMD  call  short  2024-11-15   167.5  0.0306 -0.0470       1.0
# 2    GOOGL  call  short  2024-11-15   187.5  0.0628 -0.0469       1.0
# 1      TSM  call  short  2024-11-15   212.5  0.1627 -0.1783       1.0
# 0     NVDA  call  short  2024-11-15   152.5  0.2302 -0.1490       1.0
# 4     INTC  call  short  2024-11-15    25.0  0.7526 -0.0360       2.0
# 5     NVDA  call  short  2024-11-15   146.0  0.5841 -0.1953       3.0
# 3     TSLA  call  short  2024-11-15   237.5  0.9795 -0.2037       1.0
# sum    NaN   NaN    NaN         NaN     NaN     NaN     NaN       NaN
#
#      current price  total value  total cost  total return
# 12           54.55      16365.0     12090.0        4275.0
# 10          135.05      13505.0      5100.0        8405.0
# 8            64.40       6440.0      4034.0        2406.0
# 11           54.00       5400.0      2849.0        2551.0
# 7            41.83       4183.0      4450.0        -267.0
# 9             7.97       1594.0      1200.0         394.0
# 6            -0.10        -10.0      -110.0         100.0
# 2            -0.14        -14.0       -68.0          54.0
# 1            -0.83        -83.0      -222.0         139.0
# 0            -0.88        -88.0       -93.0           5.0
# 4            -1.19       -238.0      -100.0        -138.0
# 5            -3.33       -999.0      -504.0        -495.0
# 3           -84.65      -8465.0      -429.0       -8036.0
# sum            NaN      37590.0     28197.0        9393.0

# %%
ceil(120/100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ceil(120/100)
#
# NameError: name 'ceil' is not defined

# %%
import math
math.floor(120/100)
# Out:
# 1

# %%
120/100
# Out:
# 1.2

# %%
import math
math.floor(120/100)
# Out:
# 1

# %%
270/100
# Out:
# 2.7

# %%
logger.info('test')
# Out:
# [2024-11-10 10:02:23,949] {<ipython-input-11-3c205f9073b0>:1} INFO - test

# %%
logger.info('test\n')
# Out:
# [2024-11-10 10:02:33,688] {<ipython-input-12-b0c7f354dc7a>:1} INFO - test

# %%
options_rh = rh.options.find_options_by_expiration('NVDA', '2024-11-22', 'call')
# Out:
# Found Additional pages.
# Loading page 2 ...
# Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data Loading Market Data

# %%
options_rh[0]
# Out:
# {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#  'chain_symbol': 'NVDA',
#  'created_at': '2024-10-04T01:05:04.050204Z',
#  'expiration_date': '2024-11-22',
#  'id': 'ff9ec866-e8fd-44a3-8ffd-fb001107b3f6',
#  'issue_date': '2024-10-04',
#  'min_ticks': {'above_tick': '0.05',
#   'below_tick': '0.01',
#   'cutoff_price': '3.00'},
#  'rhs_tradability': 'tradable',
#  'state': 'active',
#  'strike_price': '78.0000',
#  'tradability': 'tradable',
#  'type': 'call',
#  'updated_at': '2024-11-08T20:59:59.990924288Z',
#  'url': 'https://api.robinhood.com/options/instruments/ff9ec866-e8fd-44a3-8ffd-fb001107b3f6/',
#  'sellout_datetime': '2024-11-22T20:30:00+00:00',
#  'long_strategy_code': 'ff9ec866-e8fd-44a3-8ffd-fb001107b3f6_L1',
#  'short_strategy_code': 'ff9ec866-e8fd-44a3-8ffd-fb001107b3f6_S1',
#  'adjusted_mark_price': '69.800000',
#  'adjusted_mark_price_round_down': '69.800000',
#  'ask_price': '71.200000',
#  'ask_size': 25,
#  'bid_price': '68.400000',
#  'bid_size': 21,
#  'break_even_price': '147.800000',
#  'high_price': None,
#  'instrument': 'https://api.robinhood.com/options/instruments/ff9ec866-e8fd-44a3-8ffd-fb001107b3f6/',
#  'instrument_id': 'ff9ec866-e8fd-44a3-8ffd-fb001107b3f6',
#  'last_trade_price': '59.070000',
#  'last_trade_size': 14,
#  'low_price': None,
#  'mark_price': '69.800000',
#  'open_interest': 297,
#  'previous_close_date': '2024-11-07',
#  'previous_close_price': '71.100000',
#  'volume': 0,
#  'symbol': 'NVDA',
#  'occ_symbol': 'NVDA  241122C00078000',
#  'chance_of_profit_long': '0.440237',
#  'chance_of_profit_short': '0.559763',
#  'delta': '0.989152',
#  'gamma': '0.000658',
#  'implied_volatility': '1.636073',
#  'rho': '0.025159',
#  'theta': '-0.061774',
#  'vega': '0.007673',
#  'pricing_model': 'Bjerksund-Stensland 1993',
#  'high_fill_rate_buy_price': '70.320000',
#  'high_fill_rate_sell_price': '69.279000',
#  'low_fill_rate_buy_price': '68.908000',
#  'low_fill_rate_sell_price': '70.691000'}

# %%
filtered_options_rh = [
            option for option in options_rh 
            if float(option['mark_price']) > 3.73 and float(option['strike_price']) > 146
        ]

# %%
len(filtered_options_rh)
# Out:
# 6

# %%
filtered_options_rh
# Out:
# [{'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.049267Z',
#   'expiration_date': '2024-11-22',
#   'id': 'da74125d-9b10-4c74-947a-0da5c45f75b5',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '147.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.994603008Z',
#   'url': 'https://api.robinhood.com/options/instruments/da74125d-9b10-4c74-947a-0da5c45f75b5/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'da74125d-9b10-4c74-947a-0da5c45f75b5_L1',
#   'short_strategy_code': 'da74125d-9b10-4c74-947a-0da5c45f75b5_S1',
#   'adjusted_mark_price': '7.300000',
#   'adjusted_mark_price_round_down': '7.300000',
#   'ask_price': '7.400000',
#   'ask_size': 10,
#   'bid_price': '7.200000',
#   'bid_size': 35,
#   'break_even_price': '154.300000',
#   'high_price': '8.580000',
#   'instrument': 'https://api.robinhood.com/options/instruments/da74125d-9b10-4c74-947a-0da5c45f75b5/',
#   'instrument_id': 'da74125d-9b10-4c74-947a-0da5c45f75b5',
#   'last_trade_price': '7.320000',
#   'last_trade_size': 1,
#   'low_price': '6.660000',
#   'mark_price': '7.300000',
#   'open_interest': 2652,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '8.230000',
#   'volume': 5211,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00147000',
#   'chance_of_profit_long': '0.334521',
#   'chance_of_profit_short': '0.665479',
#   'delta': '0.540189',
#   'gamma': '0.022782',
#   'implied_volatility': '0.649765',
#   'rho': '0.023928',
#   'theta': '-0.295877',
#   'vega': '0.106450',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '7.345000',
#   'high_fill_rate_sell_price': '7.254000',
#   'low_fill_rate_buy_price': '7.246000',
#   'low_fill_rate_sell_price': '7.353000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.051605Z',
#   'expiration_date': '2024-11-22',
#   'id': 'c70af1b2-6cc0-4b4f-9673-214e191ca5df',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '149.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.996099072Z',
#   'url': 'https://api.robinhood.com/options/instruments/c70af1b2-6cc0-4b4f-9673-214e191ca5df/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'c70af1b2-6cc0-4b4f-9673-214e191ca5df_L1',
#   'short_strategy_code': 'c70af1b2-6cc0-4b4f-9673-214e191ca5df_S1',
#   'adjusted_mark_price': '6.350000',
#   'adjusted_mark_price_round_down': '6.350000',
#   'ask_price': '6.450000',
#   'ask_size': 8,
#   'bid_price': '6.250000',
#   'bid_size': 22,
#   'break_even_price': '155.350000',
#   'high_price': '7.550000',
#   'instrument': 'https://api.robinhood.com/options/instruments/c70af1b2-6cc0-4b4f-9673-214e191ca5df/',
#   'instrument_id': 'c70af1b2-6cc0-4b4f-9673-214e191ca5df',
#   'last_trade_price': '6.350000',
#   'last_trade_size': 11,
#   'low_price': '5.780000',
#   'mark_price': '6.350000',
#   'open_interest': 5249,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '7.250000',
#   'volume': 3369,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00149000',
#   'chance_of_profit_long': '0.313676',
#   'chance_of_profit_short': '0.686324',
#   'delta': '0.494540',
#   'gamma': '0.022921',
#   'implied_volatility': '0.648722',
#   'rho': '0.022017',
#   'theta': '-0.296110',
#   'vega': '0.106984',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '6.393000',
#   'high_fill_rate_sell_price': '6.306000',
#   'low_fill_rate_buy_price': '6.293000',
#   'low_fill_rate_sell_price': '6.406000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.051435Z',
#   'expiration_date': '2024-11-22',
#   'id': '69b8358a-bae3-4b6e-a948-ddb0500246bc',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '155.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.84805376Z',
#   'url': 'https://api.robinhood.com/options/instruments/69b8358a-bae3-4b6e-a948-ddb0500246bc/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': '69b8358a-bae3-4b6e-a948-ddb0500246bc_L1',
#   'short_strategy_code': '69b8358a-bae3-4b6e-a948-ddb0500246bc_S1',
#   'adjusted_mark_price': '4.000000',
#   'adjusted_mark_price_round_down': '4.000000',
#   'ask_price': '4.050000',
#   'ask_size': 19,
#   'bid_price': '3.950000',
#   'bid_size': 182,
#   'break_even_price': '159.000000',
#   'high_price': '4.900000',
#   'instrument': 'https://api.robinhood.com/options/instruments/69b8358a-bae3-4b6e-a948-ddb0500246bc/',
#   'instrument_id': '69b8358a-bae3-4b6e-a948-ddb0500246bc',
#   'last_trade_price': '3.970000',
#   'last_trade_size': 4,
#   'low_price': '3.540000',
#   'mark_price': '4.000000',
#   'open_interest': 27070,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '4.650000',
#   'volume': 10792,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00155000',
#   'chance_of_profit_long': '0.245899',
#   'chance_of_profit_short': '0.754101',
#   'delta': '0.362197',
#   'gamma': '0.021745',
#   'implied_volatility': '0.642911',
#   'rho': '0.016340',
#   'theta': '-0.274181',
#   'vega': '0.100545',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '4.027000',
#   'high_fill_rate_sell_price': '3.972000',
#   'low_fill_rate_buy_price': '3.979000',
#   'low_fill_rate_sell_price': '4.020000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.049073Z',
#   'expiration_date': '2024-11-22',
#   'id': '6003a6ea-9089-4bf5-8dfd-767a761a4c9c',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '148.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.996106496Z',
#   'url': 'https://api.robinhood.com/options/instruments/6003a6ea-9089-4bf5-8dfd-767a761a4c9c/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': '6003a6ea-9089-4bf5-8dfd-767a761a4c9c_L1',
#   'short_strategy_code': '6003a6ea-9089-4bf5-8dfd-767a761a4c9c_S1',
#   'adjusted_mark_price': '6.800000',
#   'adjusted_mark_price_round_down': '6.800000',
#   'ask_price': '6.900000',
#   'ask_size': 62,
#   'bid_price': '6.700000',
#   'bid_size': 13,
#   'break_even_price': '154.800000',
#   'high_price': '8.060000',
#   'instrument': 'https://api.robinhood.com/options/instruments/6003a6ea-9089-4bf5-8dfd-767a761a4c9c/',
#   'instrument_id': '6003a6ea-9089-4bf5-8dfd-767a761a4c9c',
#   'last_trade_price': '6.800000',
#   'last_trade_size': 5,
#   'low_price': '6.250000',
#   'mark_price': '6.800000',
#   'open_interest': 3647,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '7.700000',
#   'volume': 3869,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00148000',
#   'chance_of_profit_long': '0.324274',
#   'chance_of_profit_short': '0.675726',
#   'delta': '0.517276',
#   'gamma': '0.022936',
#   'implied_volatility': '0.647977',
#   'rho': '0.022976',
#   'theta': '-0.295910',
#   'vega': '0.106893',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '6.842000',
#   'high_fill_rate_sell_price': '6.757000',
#   'low_fill_rate_buy_price': '6.742000',
#   'low_fill_rate_sell_price': '6.857000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.049567Z',
#   'expiration_date': '2024-11-22',
#   'id': '491d4f52-b2a0-4399-b98f-a1e8ad25669e',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '150.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.996071936Z',
#   'url': 'https://api.robinhood.com/options/instruments/491d4f52-b2a0-4399-b98f-a1e8ad25669e/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': '491d4f52-b2a0-4399-b98f-a1e8ad25669e_L1',
#   'short_strategy_code': '491d4f52-b2a0-4399-b98f-a1e8ad25669e_S1',
#   'adjusted_mark_price': '5.930000',
#   'adjusted_mark_price_round_down': '5.920000',
#   'ask_price': '6.000000',
#   'ask_size': 6,
#   'bid_price': '5.850000',
#   'bid_size': 278,
#   'break_even_price': '155.930000',
#   'high_price': '7.050000',
#   'instrument': 'https://api.robinhood.com/options/instruments/491d4f52-b2a0-4399-b98f-a1e8ad25669e/',
#   'instrument_id': '491d4f52-b2a0-4399-b98f-a1e8ad25669e',
#   'last_trade_price': '5.950000',
#   'last_trade_size': 80,
#   'low_price': '5.350000',
#   'mark_price': '5.925000',
#   'open_interest': 39250,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '6.750000',
#   'volume': 24719,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00150000',
#   'chance_of_profit_long': '0.302879',
#   'chance_of_profit_short': '0.697121',
#   'delta': '0.472112',
#   'gamma': '0.022825',
#   'implied_volatility': '0.650212',
#   'rho': '0.021061',
#   'theta': '-0.295724',
#   'vega': '0.106731',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '5.966000',
#   'high_fill_rate_sell_price': '5.883000',
#   'low_fill_rate_buy_price': '5.892000',
#   'low_fill_rate_sell_price': '5.957000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-24T01:06:05.692164Z',
#   'expiration_date': '2024-11-22',
#   'id': '1797f24d-73b7-4c84-85a9-551b79369e2d',
#   'issue_date': '2024-10-24',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '152.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.996998656Z',
#   'url': 'https://api.robinhood.com/options/instruments/1797f24d-73b7-4c84-85a9-551b79369e2d/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': '1797f24d-73b7-4c84-85a9-551b79369e2d_L1',
#   'short_strategy_code': '1797f24d-73b7-4c84-85a9-551b79369e2d_S1',
#   'adjusted_mark_price': '4.880000',
#   'adjusted_mark_price_round_down': '4.870000',
#   'ask_price': '4.950000',
#   'ask_size': 22,
#   'bid_price': '4.800000',
#   'bid_size': 35,
#   'break_even_price': '157.380000',
#   'high_price': '5.900000',
#   'instrument': 'https://api.robinhood.com/options/instruments/1797f24d-73b7-4c84-85a9-551b79369e2d/',
#   'instrument_id': '1797f24d-73b7-4c84-85a9-551b79369e2d',
#   'last_trade_price': '4.900000',
#   'last_trade_size': 50,
#   'low_price': '4.400000',
#   'mark_price': '4.875000',
#   'open_interest': 6892,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '5.630000',
#   'volume': 3445,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00152500',
#   'chance_of_profit_long': '0.274787',
#   'chance_of_profit_short': '0.725213',
#   'delta': '0.415858',
#   'gamma': '0.022548',
#   'implied_volatility': '0.644848',
#   'rho': '0.018665',
#   'theta': '-0.286739',
#   'vega': '0.104604',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '4.911000',
#   'high_fill_rate_sell_price': '4.838000',
#   'low_fill_rate_buy_price': '4.837000',
#   'low_fill_rate_sell_price': '4.912000'}]

# %%
optionTable = []
    for option in filtered_options_rh:
        row = { 'symbol': option.symbol,
                'type': option.type,
                'exp': option.exp,
                'strike': option.strike,
                'delta': option.get_delta(),
                'theta': option.get_theta(),
                'quantity': abs(option.quantity),
                'current price': round(option.get_mark_price(), 2)
                }
        optionTable.append(row)
# Out:
#   Cell In[18], line 2
#     for option in filtered_options_rh:
#     ^
# IndentationError: unexpected indent

# %%
optionTable = []
for option in filtered_options_rh:
    row = { 'symbol': option.symbol,
            'type': option.type,
            'exp': option.exp,
            'strike': option.strike,
            'delta': option.get_delta(),
            'theta': option.get_theta(),
            'quantity': abs(option.quantity),
            'current price': round(option.get_mark_price(), 2)
            }
    optionTable.append(row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 3
#       1 optionTable = []
#       2 for option in filtered_options_rh:
# ----> 3     row = { 'symbol': option.symbol,
#       4             'type': option.type,
#       5             'exp': option.exp,
#       6             'strike': option.strike,
#       7             'delta': option.get_delta(),
#       8             'theta': option.get_theta(),
#       9             'quantity': abs(option.quantity),
#      10             'current price': round(option.get_mark_price(), 2)
#      11             }
#      12     optionTable.append(row)
#
# AttributeError: 'dict' object has no attribute 'symbol'

# %%
matchingOptions = []
for option_rh in options_rh:
    if float(option['mark_price']) > self.get_mark_price() and float(option['strike_price']) > self.strike:
    option = Option(self.symbol, option_rh['expiration_date'], float(option_rh['strike_price']), option_rh['type'])
    matchingOptions.append(option)    
optionTable = []
for option in matchingOptions:
    row = { 'symbol': option.symbol,
            'type': option.type,
            'exp': option.exp,
            'strike': option.strike,
            'delta': option.get_delta(),
            'theta': option.get_theta(),
            'quantity': abs(option.quantity),
            'current price': round(option.get_mark_price(), 2)
            }
    optionTable.append(row)
# Out:
#   Cell In[20], line 4
#     option = Option(self.symbol, option_rh['expiration_date'], float(option_rh['strike_price']), option_rh['type'])
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
matchingOptions = []
for option_rh in options_rh:
    if float(option['mark_price']) > self.get_mark_price() and float(option['strike_price']) > self.strike:
        option = Option(self.symbol, option_rh['expiration_date'], float(option_rh['strike_price']), option_rh['type'])
        matchingOptions.append(option)    

optionTable = []
for option in matchingOptions:
    row = { 'symbol': option.symbol,
            'type': option.type,
            'exp': option.exp,
            'strike': option.strike,
            'delta': option.get_delta(),
            'theta': option.get_theta(),
            'quantity': abs(option.quantity),
            'current price': round(option.get_mark_price(), 2)
            }
    optionTable.append(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 matchingOptions = []
#       2 for option_rh in options_rh:
# ----> 3     if float(option['mark_price']) > self.get_mark_price() and float(option['strike_price']) > self.strike:
#       4         option = Option(self.symbol, option_rh['expiration_date'], float(option_rh['strike_price']), option_rh['type'])
#       5         matchingOptions.append(option)
#
# NameError: name 'self' is not defined

# %%
matchingOptions = []
for option_rh in options_rh:
    if float(option['mark_price']) > 3.73 and float(option['strike_price']) > 148:
        option = Option(self.symbol, option_rh['expiration_date'], float(option_rh['strike_price']), option_rh['type'])
        matchingOptions.append(option)    

optionTable = []
for option in matchingOptions:
    row = { 'symbol': option.symbol,
            'type': option.type,
            'exp': option.exp,
            'strike': option.strike,
            'delta': option.get_delta(),
            'theta': option.get_theta(),
            'quantity': abs(option.quantity),
            'current price': round(option.get_mark_price(), 2)
            }
    optionTable.append(row)

# %%
optionTable
# Out:
# []

# %%
options_rh
# Out:
# [{'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.050204Z',
#   'expiration_date': '2024-11-22',
#   'id': 'ff9ec866-e8fd-44a3-8ffd-fb001107b3f6',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '78.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.990924288Z',
#   'url': 'https://api.robinhood.com/options/instruments/ff9ec866-e8fd-44a3-8ffd-fb001107b3f6/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'ff9ec866-e8fd-44a3-8ffd-fb001107b3f6_L1',
#   'short_strategy_code': 'ff9ec866-e8fd-44a3-8ffd-fb001107b3f6_S1',
#   'adjusted_mark_price': '69.800000',
#   'adjusted_mark_price_round_down': '69.800000',
#   'ask_price': '71.200000',
#   'ask_size': 25,
#   'bid_price': '68.400000',
#   'bid_size': 21,
#   'break_even_price': '147.800000',
#   'high_price': None,
#   'instrument': 'https://api.robinhood.com/options/instruments/ff9ec866-e8fd-44a3-8ffd-fb001107b3f6/',
#   'instrument_id': 'ff9ec866-e8fd-44a3-8ffd-fb001107b3f6',
#   'last_trade_price': '59.070000',
#   'last_trade_size': 14,
#   'low_price': None,
#   'mark_price': '69.800000',
#   'open_interest': 297,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '71.100000',
#   'volume': 0,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00078000',
#   'chance_of_profit_long': '0.440237',
#   'chance_of_profit_short': '0.559763',
#   'delta': '0.989152',
#   'gamma': '0.000658',
#   'implied_volatility': '1.636073',
#   'rho': '0.025159',
#   'theta': '-0.061774',
#   'vega': '0.007673',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '70.320000',
#   'high_fill_rate_sell_price': '69.279000',
#   'low_fill_rate_buy_price': '68.908000',
#   'low_fill_rate_sell_price': '70.691000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-03T01:06:51.481133Z',
#   'expiration_date': '2024-11-22',
#   'id': 'fe91f64d-a19e-494d-a5eb-85f473e1a4e3',
#   'issue_date': '2024-10-03',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '105.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.987726592Z',
#   'url': 'https://api.robinhood.com/options/instruments/fe91f64d-a19e-494d-a5eb-85f473e1a4e3/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'fe91f64d-a19e-494d-a5eb-85f473e1a4e3_L1',
#   'short_strategy_code': 'fe91f64d-a19e-494d-a5eb-85f473e1a4e3_S1',
#   'adjusted_mark_price': '43.500000',
#   'adjusted_mark_price_round_down': '43.500000',
#   'ask_price': '44.200000',
#   'ask_size': 18,
#   'bid_price': '42.800000',
#   'bid_size': 45,
#   'break_even_price': '148.500000',
#   'high_price': '43.090000',
#   'instrument': 'https://api.robinhood.com/options/instruments/fe91f64d-a19e-494d-a5eb-85f473e1a4e3/',
#   'instrument_id': 'fe91f64d-a19e-494d-a5eb-85f473e1a4e3',
#   'last_trade_price': '42.550000',
#   'last_trade_size': 1,
#   'low_price': '42.550000',
#   'mark_price': '43.500000',
#   'open_interest': 234,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '44.280000',
#   'volume': 13,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00105000',
#   'chance_of_profit_long': '0.445518',
#   'chance_of_profit_short': '0.554482',
#   'delta': '0.946217',
#   'gamma': '0.003243',
#   'implied_volatility': '1.255944',
#   'rho': '0.031760',
#   'theta': '-0.164849',
#   'vega': '0.029311',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '43.826000',
#   'high_fill_rate_sell_price': '43.173000',
#   'low_fill_rate_buy_price': '43.135000',
#   'low_fill_rate_sell_price': '43.864000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.049907Z',
#   'expiration_date': '2024-11-22',
#   'id': 'fbba2f46-ea5b-49af-b7b1-19899c5f261e',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '100.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.98929024Z',
#   'url': 'https://api.robinhood.com/options/instruments/fbba2f46-ea5b-49af-b7b1-19899c5f261e/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'fbba2f46-ea5b-49af-b7b1-19899c5f261e_L1',
#   'short_strategy_code': 'fbba2f46-ea5b-49af-b7b1-19899c5f261e_S1',
#   'adjusted_mark_price': '47.950000',
#   'adjusted_mark_price_round_down': '47.950000',
#   'ask_price': '49.200000',
#   'ask_size': 18,
#   'bid_price': '46.700000',
#   'bid_size': 18,
#   'break_even_price': '147.950000',
#   'high_price': '47.840000',
#   'instrument': 'https://api.robinhood.com/options/instruments/fbba2f46-ea5b-49af-b7b1-19899c5f261e/',
#   'instrument_id': 'fbba2f46-ea5b-49af-b7b1-19899c5f261e',
#   'last_trade_price': '47.600000',
#   'last_trade_size': 1,
#   'low_price': '47.530000',
#   'mark_price': '47.950000',
#   'open_interest': 420,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '49.250000',
#   'volume': 53,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00100000',
#   'chance_of_profit_long': '0.455733',
#   'chance_of_profit_short': '0.544267',
#   'delta': '0.976166',
#   'gamma': '0.001830',
#   'implied_volatility': '1.143739',
#   'rho': '0.031750',
#   'theta': '-0.083676',
#   'vega': '0.015059',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '48.416000',
#   'high_fill_rate_sell_price': '47.483000',
#   'low_fill_rate_buy_price': '47.156000',
#   'low_fill_rate_sell_price': '48.743000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.050545Z',
#   'expiration_date': '2024-11-22',
#   'id': 'fb5af5b1-cd0c-49fc-aab8-381cee5b1d6c',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '190.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.901636608Z',
#   'url': 'https://api.robinhood.com/options/instruments/fb5af5b1-cd0c-49fc-aab8-381cee5b1d6c/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'fb5af5b1-cd0c-49fc-aab8-381cee5b1d6c_L1',
#   'short_strategy_code': 'fb5af5b1-cd0c-49fc-aab8-381cee5b1d6c_S1',
#   'adjusted_mark_price': '0.200000',
#   'adjusted_mark_price_round_down': '0.200000',
#   'ask_price': '0.210000',
#   'ask_size': 60,
#   'bid_price': '0.190000',
#   'bid_size': 215,
#   'break_even_price': '190.200000',
#   'high_price': '0.230000',
#   'instrument': 'https://api.robinhood.com/options/instruments/fb5af5b1-cd0c-49fc-aab8-381cee5b1d6c/',
#   'instrument_id': 'fb5af5b1-cd0c-49fc-aab8-381cee5b1d6c',
#   'last_trade_price': '0.200000',
#   'last_trade_size': 5,
#   'low_price': '0.160000',
#   'mark_price': '0.200000',
#   'open_interest': 2638,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '0.210000',
#   'volume': 717,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00190000',
#   'chance_of_profit_long': '0.020870',
#   'chance_of_profit_short': '0.979130',
#   'delta': '0.028733',
#   'gamma': '0.003474',
#   'implied_volatility': '0.704750',
#   'rho': '0.001335',
#   'theta': '-0.051928',
#   'vega': '0.017606',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '0.206000',
#   'high_fill_rate_sell_price': '0.193000',
#   'low_fill_rate_buy_price': '0.197000',
#   'low_fill_rate_sell_price': '0.202000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.051285Z',
#   'expiration_date': '2024-11-22',
#   'id': 'f9b0c302-fda9-427c-a9b3-134dd66975ba',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '71.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.991229952Z',
#   'url': 'https://api.robinhood.com/options/instruments/f9b0c302-fda9-427c-a9b3-134dd66975ba/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'f9b0c302-fda9-427c-a9b3-134dd66975ba_L1',
#   'short_strategy_code': 'f9b0c302-fda9-427c-a9b3-134dd66975ba_S1',
#   'adjusted_mark_price': '76.750000',
#   'adjusted_mark_price_round_down': '76.750000',
#   'ask_price': '78.150000',
#   'ask_size': 25,
#   'bid_price': '75.350000',
#   'bid_size': 21,
#   'break_even_price': '147.750000',
#   'high_price': None,
#   'instrument': 'https://api.robinhood.com/options/instruments/f9b0c302-fda9-427c-a9b3-134dd66975ba/',
#   'instrument_id': 'f9b0c302-fda9-427c-a9b3-134dd66975ba',
#   'last_trade_price': None,
#   'last_trade_size': None,
#   'low_price': None,
#   'mark_price': '76.750000',
#   'open_interest': 0,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '78.080000',
#   'volume': 0,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00071000',
#   'chance_of_profit_long': '0.435107',
#   'chance_of_profit_short': '0.564893',
#   'delta': '0.992053',
#   'gamma': '0.000458',
#   'implied_volatility': '1.792237',
#   'rho': '0.023003',
#   'theta': '-0.052322',
#   'vega': '0.005845',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '77.270000',
#   'high_fill_rate_sell_price': '76.229000',
#   'low_fill_rate_buy_price': '75.858000',
#   'low_fill_rate_sell_price': '77.641000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.051477Z',
#   'expiration_date': '2024-11-22',
#   'id': 'ed9cd3c8-f17c-4484-874e-fa63cb1a172b',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '77.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.9909504Z',
#   'url': 'https://api.robinhood.com/options/instruments/ed9cd3c8-f17c-4484-874e-fa63cb1a172b/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'ed9cd3c8-f17c-4484-874e-fa63cb1a172b_L1',
#   'short_strategy_code': 'ed9cd3c8-f17c-4484-874e-fa63cb1a172b_S1',
#   'adjusted_mark_price': '70.800000',
#   'adjusted_mark_price_round_down': '70.800000',
#   'ask_price': '72.200000',
#   'ask_size': 25,
#   'bid_price': '69.400000',
#   'bid_size': 21,
#   'break_even_price': '147.800000',
#   'high_price': None,
#   'instrument': 'https://api.robinhood.com/options/instruments/ed9cd3c8-f17c-4484-874e-fa63cb1a172b/',
#   'instrument_id': 'ed9cd3c8-f17c-4484-874e-fa63cb1a172b',
#   'last_trade_price': None,
#   'last_trade_size': None,
#   'low_price': None,
#   'mark_price': '70.800000',
#   'open_interest': 0,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '72.080000',
#   'volume': 0,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00077000',
#   'chance_of_profit_long': '0.439106',
#   'chance_of_profit_short': '0.560894',
#   'delta': '0.989277',
#   'gamma': '0.000634',
#   'implied_volatility': '1.667961',
#   'rho': '0.024835',
#   'theta': '-0.062128',
#   'vega': '0.007596',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '71.320000',
#   'high_fill_rate_sell_price': '70.279000',
#   'low_fill_rate_buy_price': '69.908000',
#   'low_fill_rate_sell_price': '71.691000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.051264Z',
#   'expiration_date': '2024-11-22',
#   'id': 'ed760945-8523-4daf-92fe-61ecfc87530c',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '82.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.990804736Z',
#   'url': 'https://api.robinhood.com/options/instruments/ed760945-8523-4daf-92fe-61ecfc87530c/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'ed760945-8523-4daf-92fe-61ecfc87530c_L1',
#   'short_strategy_code': 'ed760945-8523-4daf-92fe-61ecfc87530c_S1',
#   'adjusted_mark_price': '65.850000',
#   'adjusted_mark_price_round_down': '65.850000',
#   'ask_price': '67.200000',
#   'ask_size': 21,
#   'bid_price': '64.500000',
#   'bid_size': 21,
#   'break_even_price': '147.850000',
#   'high_price': None,
#   'instrument': 'https://api.robinhood.com/options/instruments/ed760945-8523-4daf-92fe-61ecfc87530c/',
#   'instrument_id': 'ed760945-8523-4daf-92fe-61ecfc87530c',
#   'last_trade_price': '55.000000',
#   'last_trade_size': 1,
#   'low_price': None,
#   'mark_price': '65.850000',
#   'open_interest': 139,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '67.100000',
#   'volume': 0,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00082000',
#   'chance_of_profit_long': '0.442115',
#   'chance_of_profit_short': '0.557885',
#   'delta': '0.986270',
#   'gamma': '0.000833',
#   'implied_volatility': '1.569912',
#   'rho': '0.026325',
#   'theta': '-0.071428',
#   'vega': '0.009411',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '66.354000',
#   'high_fill_rate_sell_price': '65.345000',
#   'low_fill_rate_buy_price': '64.993000',
#   'low_fill_rate_sell_price': '66.706000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.050311Z',
#   'expiration_date': '2024-11-22',
#   'id': 'ecb86ae8-393a-44a8-81de-2035103fbb6e',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '180.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.529103872Z',
#   'url': 'https://api.robinhood.com/options/instruments/ecb86ae8-393a-44a8-81de-2035103fbb6e/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'ecb86ae8-393a-44a8-81de-2035103fbb6e_L1',
#   'short_strategy_code': 'ecb86ae8-393a-44a8-81de-2035103fbb6e_S1',
#   'adjusted_mark_price': '0.410000',
#   'adjusted_mark_price_round_down': '0.410000',
#   'ask_price': '0.420000',
#   'ask_size': 116,
#   'bid_price': '0.400000',
#   'bid_size': 82,
#   'break_even_price': '180.410000',
#   'high_price': '0.500000',
#   'instrument': 'https://api.robinhood.com/options/instruments/ecb86ae8-393a-44a8-81de-2035103fbb6e/',
#   'instrument_id': 'ecb86ae8-393a-44a8-81de-2035103fbb6e',
#   'last_trade_price': '0.420000',
#   'last_trade_size': 1,
#   'low_price': '0.330000',
#   'mark_price': '0.410000',
#   'open_interest': 4320,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '0.480000',
#   'volume': 2901,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00180000',
#   'chance_of_profit_long': '0.042499',
#   'chance_of_profit_short': '0.957501',
#   'delta': '0.056683',
#   'gamma': '0.006421',
#   'implied_volatility': '0.661239',
#   'rho': '0.002629',
#   'theta': '-0.084727',
#   'vega': '0.030553',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '0.416000',
#   'high_fill_rate_sell_price': '0.403000',
#   'low_fill_rate_buy_price': '0.406000',
#   'low_fill_rate_sell_price': '0.413000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.048987Z',
#   'expiration_date': '2024-11-22',
#   'id': 'e99759ad-1f1b-4746-9a81-a9db2aaf6ca9',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '106.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.98747136Z',
#   'url': 'https://api.robinhood.com/options/instruments/e99759ad-1f1b-4746-9a81-a9db2aaf6ca9/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'e99759ad-1f1b-4746-9a81-a9db2aaf6ca9_L1',
#   'short_strategy_code': 'e99759ad-1f1b-4746-9a81-a9db2aaf6ca9_S1',
#   'adjusted_mark_price': '42.000000',
#   'adjusted_mark_price_round_down': '42.000000',
#   'ask_price': '43.350000',
#   'ask_size': 32,
#   'bid_price': '40.650000',
#   'bid_size': 21,
#   'break_even_price': '148.000000',
#   'high_price': '41.640000',
#   'instrument': 'https://api.robinhood.com/options/instruments/e99759ad-1f1b-4746-9a81-a9db2aaf6ca9/',
#   'instrument_id': 'e99759ad-1f1b-4746-9a81-a9db2aaf6ca9',
#   'last_trade_price': '41.640000',
#   'last_trade_size': 1,
#   'low_price': '41.640000',
#   'mark_price': '42.000000',
#   'open_interest': 76,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '43.280000',
#   'volume': 1,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00106000',
#   'chance_of_profit_long': '0.459163',
#   'chance_of_profit_short': '0.540837',
#   'delta': '0.970244',
#   'gamma': '0.002473',
#   'implied_volatility': '1.018867',
#   'rho': '0.033428',
#   'theta': '-0.089481',
#   'vega': '0.018125',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '42.507000',
#   'high_fill_rate_sell_price': '41.492000',
#   'low_fill_rate_buy_price': '41.147000',
#   'low_fill_rate_sell_price': '42.852000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-03T01:06:51.480714Z',
#   'expiration_date': '2024-11-22',
#   'id': 'e4ebd33d-5d0a-4392-942d-30f20ef993c0',
#   'issue_date': '2024-10-03',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '119.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.984634624Z',
#   'url': 'https://api.robinhood.com/options/instruments/e4ebd33d-5d0a-4392-942d-30f20ef993c0/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'e4ebd33d-5d0a-4392-942d-30f20ef993c0_L1',
#   'short_strategy_code': 'e4ebd33d-5d0a-4392-942d-30f20ef993c0_S1',
#   'adjusted_mark_price': '29.830000',
#   'adjusted_mark_price_round_down': '29.820000',
#   'ask_price': '30.600000',
#   'ask_size': 32,
#   'bid_price': '29.050000',
#   'bid_size': 57,
#   'break_even_price': '148.830000',
#   'high_price': '30.170000',
#   'instrument': 'https://api.robinhood.com/options/instruments/e4ebd33d-5d0a-4392-942d-30f20ef993c0/',
#   'instrument_id': 'e4ebd33d-5d0a-4392-942d-30f20ef993c0',
#   'last_trade_price': '28.750000',
#   'last_trade_size': 1,
#   'low_price': '28.140000',
#   'mark_price': '29.825000',
#   'open_interest': 159,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '30.650000',
#   'volume': 72,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00119000',
#   'chance_of_profit_long': '0.448543',
#   'chance_of_profit_short': '0.551457',
#   'delta': '0.909745',
#   'gamma': '0.006393',
#   'implied_volatility': '0.949278',
#   'rho': '0.034501',
#   'theta': '-0.185045',
#   'vega': '0.043644',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '30.189000',
#   'high_fill_rate_sell_price': '29.460000',
#   'low_fill_rate_buy_price': '29.426000',
#   'low_fill_rate_sell_price': '30.223000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.049695Z',
#   'expiration_date': '2024-11-22',
#   'id': 'e4255388-4684-4109-81fd-bd5626567e51',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '134.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.973933824Z',
#   'url': 'https://api.robinhood.com/options/instruments/e4255388-4684-4109-81fd-bd5626567e51/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'e4255388-4684-4109-81fd-bd5626567e51_L1',
#   'short_strategy_code': 'e4255388-4684-4109-81fd-bd5626567e51_S1',
#   'adjusted_mark_price': '15.800000',
#   'adjusted_mark_price_round_down': '15.800000',
#   'ask_price': '16.150000',
#   'ask_size': 28,
#   'bid_price': '15.450000',
#   'bid_size': 16,
#   'break_even_price': '149.800000',
#   'high_price': '17.510000',
#   'instrument': 'https://api.robinhood.com/options/instruments/e4255388-4684-4109-81fd-bd5626567e51/',
#   'instrument_id': 'e4255388-4684-4109-81fd-bd5626567e51',
#   'last_trade_price': '15.600000',
#   'last_trade_size': 4,
#   'low_price': '14.840000',
#   'mark_price': '15.800000',
#   'open_interest': 2243,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '16.980000',
#   'volume': 115,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00134000',
#   'chance_of_profit_long': '0.430619',
#   'chance_of_profit_short': '0.569381',
#   'delta': '0.803901',
#   'gamma': '0.015277',
#   'implied_volatility': '0.675395',
#   'rho': '0.033978',
#   'theta': '-0.220815',
#   'vega': '0.074196',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '15.985000',
#   'high_fill_rate_sell_price': '15.614000',
#   'low_fill_rate_buy_price': '15.641000',
#   'low_fill_rate_sell_price': '15.958000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.051073Z',
#   'expiration_date': '2024-11-22',
#   'id': 'e3e40d40-027b-486a-a7a2-eab4758a6a0f',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '205.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.977402624Z',
#   'url': 'https://api.robinhood.com/options/instruments/e3e40d40-027b-486a-a7a2-eab4758a6a0f/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'e3e40d40-027b-486a-a7a2-eab4758a6a0f_L1',
#   'short_strategy_code': 'e3e40d40-027b-486a-a7a2-eab4758a6a0f_S1',
#   'adjusted_mark_price': '0.080000',
#   'adjusted_mark_price_round_down': '0.070000',
#   'ask_price': '0.080000',
#   'ask_size': 3,
#   'bid_price': '0.070000',
#   'bid_size': 25,
#   'break_even_price': '205.080000',
#   'high_price': '0.100000',
#   'instrument': 'https://api.robinhood.com/options/instruments/e3e40d40-027b-486a-a7a2-eab4758a6a0f/',
#   'instrument_id': 'e3e40d40-027b-486a-a7a2-eab4758a6a0f',
#   'last_trade_price': '0.080000',
#   'last_trade_size': 1,
#   'low_price': '0.070000',
#   'mark_price': '0.075000',
#   'open_interest': 3644,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '0.090000',
#   'volume': 1128,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00205000',
#   'chance_of_profit_long': '0.007990',
#   'chance_of_profit_short': '0.992010',
#   'delta': '0.011715',
#   'gamma': '0.001484',
#   'implied_volatility': '0.771210',
#   'rho': '0.000545',
#   'theta': '-0.026425',
#   'vega': '0.008204',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '0.078000',
#   'high_fill_rate_sell_price': '0.071000',
#   'low_fill_rate_buy_price': '0.073000',
#   'low_fill_rate_sell_price': '0.076000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.050098Z',
#   'expiration_date': '2024-11-22',
#   'id': 'e1a999f1-feef-4542-8809-ebd37d660416',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '68.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.991365632Z',
#   'url': 'https://api.robinhood.com/options/instruments/e1a999f1-feef-4542-8809-ebd37d660416/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'e1a999f1-feef-4542-8809-ebd37d660416_L1',
#   'short_strategy_code': 'e1a999f1-feef-4542-8809-ebd37d660416_S1',
#   'adjusted_mark_price': '79.780000',
#   'adjusted_mark_price_round_down': '79.770000',
#   'ask_price': '81.150000',
#   'ask_size': 21,
#   'bid_price': '78.400000',
#   'bid_size': 21,
#   'break_even_price': '147.780000',
#   'high_price': None,
#   'instrument': 'https://api.robinhood.com/options/instruments/e1a999f1-feef-4542-8809-ebd37d660416/',
#   'instrument_id': 'e1a999f1-feef-4542-8809-ebd37d660416',
#   'last_trade_price': '65.930000',
#   'last_trade_size': 1,
#   'low_price': None,
#   'mark_price': '79.775000',
#   'open_interest': 100,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '81.130000',
#   'volume': 0,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00068000',
#   'chance_of_profit_long': '0.429378',
#   'chance_of_profit_short': '0.570622',
#   'delta': '0.991083',
#   'gamma': '0.000455',
#   'implied_volatility': '1.946613',
#   'rho': '0.021954',
#   'theta': '-0.060669',
#   'vega': '0.006466',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '80.286000',
#   'high_fill_rate_sell_price': '79.263000',
#   'low_fill_rate_buy_price': '78.900000',
#   'low_fill_rate_sell_price': '80.649000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-03T01:06:51.480841Z',
#   'expiration_date': '2024-11-22',
#   'id': 'df086545-4c71-4a8c-90f6-070227ee21b6',
#   'issue_date': '2024-10-03',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '121.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.981822464Z',
#   'url': 'https://api.robinhood.com/options/instruments/df086545-4c71-4a8c-90f6-070227ee21b6/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'df086545-4c71-4a8c-90f6-070227ee21b6_L1',
#   'short_strategy_code': 'df086545-4c71-4a8c-90f6-070227ee21b6_S1',
#   'adjusted_mark_price': '27.480000',
#   'adjusted_mark_price_round_down': '27.470000',
#   'ask_price': '28.100000',
#   'ask_size': 73,
#   'bid_price': '26.850000',
#   'bid_size': 37,
#   'break_even_price': '148.480000',
#   'high_price': '28.750000',
#   'instrument': 'https://api.robinhood.com/options/instruments/df086545-4c71-4a8c-90f6-070227ee21b6/',
#   'instrument_id': 'df086545-4c71-4a8c-90f6-070227ee21b6',
#   'last_trade_price': '27.400000',
#   'last_trade_size': 3,
#   'low_price': '26.450000',
#   'mark_price': '27.475000',
#   'open_interest': 446,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '28.600000',
#   'volume': 48,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00121000',
#   'chance_of_profit_long': '0.456963',
#   'chance_of_profit_short': '0.543037',
#   'delta': '0.923512',
#   'gamma': '0.006613',
#   'implied_volatility': '0.809804',
#   'rho': '0.035950',
#   'theta': '-0.143248',
#   'vega': '0.038537',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '27.771000',
#   'high_fill_rate_sell_price': '27.178000',
#   'low_fill_rate_buy_price': '27.156000',
#   'low_fill_rate_sell_price': '27.793000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.048674Z',
#   'expiration_date': '2024-11-22',
#   'id': 'dd5e64d8-6314-4a90-989c-0dd765be2b5a',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '133.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.853651968Z',
#   'url': 'https://api.robinhood.com/options/instruments/dd5e64d8-6314-4a90-989c-0dd765be2b5a/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'dd5e64d8-6314-4a90-989c-0dd765be2b5a_L1',
#   'short_strategy_code': 'dd5e64d8-6314-4a90-989c-0dd765be2b5a_S1',
#   'adjusted_mark_price': '16.500000',
#   'adjusted_mark_price_round_down': '16.500000',
#   'ask_price': '16.650000',
#   'ask_size': 20,
#   'bid_price': '16.350000',
#   'bid_size': 1,
#   'break_even_price': '149.500000',
#   'high_price': '18.200000',
#   'instrument': 'https://api.robinhood.com/options/instruments/dd5e64d8-6314-4a90-989c-0dd765be2b5a/',
#   'instrument_id': 'dd5e64d8-6314-4a90-989c-0dd765be2b5a',
#   'last_trade_price': '16.320000',
#   'last_trade_size': 1,
#   'low_price': '15.550000',
#   'mark_price': '16.500000',
#   'open_interest': 1292,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '17.830000',
#   'volume': 164,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00133000',
#   'chance_of_profit_long': '0.436805',
#   'chance_of_profit_short': '0.563195',
#   'delta': '0.823723',
#   'gamma': '0.014530',
#   'implied_volatility': '0.664517',
#   'rho': '0.034713',
#   'theta': '-0.204696',
#   'vega': '0.069453',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '16.539000',
#   'high_fill_rate_sell_price': '16.460000',
#   'low_fill_rate_buy_price': '16.387000',
#   'low_fill_rate_sell_price': '16.612000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.050944Z',
#   'expiration_date': '2024-11-22',
#   'id': 'dbc55f68-d720-420c-a468-4436222d38fa',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '93.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.99001216Z',
#   'url': 'https://api.robinhood.com/options/instruments/dbc55f68-d720-420c-a468-4436222d38fa/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'dbc55f68-d720-420c-a468-4436222d38fa_L1',
#   'short_strategy_code': 'dbc55f68-d720-420c-a468-4436222d38fa_S1',
#   'adjusted_mark_price': '54.880000',
#   'adjusted_mark_price_round_down': '54.870000',
#   'ask_price': '56.250000',
#   'ask_size': 25,
#   'bid_price': '53.500000',
#   'bid_size': 21,
#   'break_even_price': '147.880000',
#   'high_price': None,
#   'instrument': 'https://api.robinhood.com/options/instruments/dbc55f68-d720-420c-a468-4436222d38fa/',
#   'instrument_id': 'dbc55f68-d720-420c-a468-4436222d38fa',
#   'last_trade_price': '45.300000',
#   'last_trade_size': 1,
#   'low_price': None,
#   'mark_price': '54.875000',
#   'open_interest': 45,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '56.100000',
#   'volume': 0,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00093000',
#   'chance_of_profit_long': '0.451968',
#   'chance_of_profit_short': '0.548032',
#   'delta': '0.982406',
#   'gamma': '0.001265',
#   'implied_volatility': '1.279041',
#   'rho': '0.029763',
#   'theta': '-0.073250',
#   'vega': '0.011644',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '55.388000',
#   'high_fill_rate_sell_price': '54.361000',
#   'low_fill_rate_buy_price': '54.001000',
#   'low_fill_rate_sell_price': '55.748000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-03T01:06:51.481197Z',
#   'expiration_date': '2024-11-22',
#   'id': 'db6e02d5-6d84-4056-b872-0159914464dd',
#   'issue_date': '2024-10-03',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '131.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.975838208Z',
#   'url': 'https://api.robinhood.com/options/instruments/db6e02d5-6d84-4056-b872-0159914464dd/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'db6e02d5-6d84-4056-b872-0159914464dd_L1',
#   'short_strategy_code': 'db6e02d5-6d84-4056-b872-0159914464dd_S1',
#   'adjusted_mark_price': '18.330000',
#   'adjusted_mark_price_round_down': '18.320000',
#   'ask_price': '18.800000',
#   'ask_size': 84,
#   'bid_price': '17.850000',
#   'bid_size': 251,
#   'break_even_price': '149.330000',
#   'high_price': '20.100000',
#   'instrument': 'https://api.robinhood.com/options/instruments/db6e02d5-6d84-4056-b872-0159914464dd/',
#   'instrument_id': 'db6e02d5-6d84-4056-b872-0159914464dd',
#   'last_trade_price': '18.320000',
#   'last_trade_size': 1,
#   'low_price': '17.550000',
#   'mark_price': '18.325000',
#   'open_interest': 1109,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '19.480000',
#   'volume': 183,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00131000',
#   'chance_of_profit_long': '0.441016',
#   'chance_of_profit_short': '0.558984',
#   'delta': '0.843559',
#   'gamma': '0.012788',
#   'implied_volatility': '0.698939',
#   'rho': '0.035076',
#   'theta': '-0.199814',
#   'vega': '0.064298',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '18.606000',
#   'high_fill_rate_sell_price': '18.043000',
#   'low_fill_rate_buy_price': '18.149000',
#   'low_fill_rate_sell_price': '18.500000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-03T01:06:51.480482Z',
#   'expiration_date': '2024-11-22',
#   'id': 'daf9bb03-1b51-4c05-96f6-a0a1c399f820',
#   'issue_date': '2024-10-03',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '107.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.994312448Z',
#   'url': 'https://api.robinhood.com/options/instruments/daf9bb03-1b51-4c05-96f6-a0a1c399f820/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'daf9bb03-1b51-4c05-96f6-a0a1c399f820_L1',
#   'short_strategy_code': 'daf9bb03-1b51-4c05-96f6-a0a1c399f820_S1',
#   'adjusted_mark_price': '41.000000',
#   'adjusted_mark_price_round_down': '41.000000',
#   'ask_price': '42.400000',
#   'ask_size': 27,
#   'bid_price': '39.600000',
#   'bid_size': 21,
#   'break_even_price': '148.000000',
#   'high_price': '40.480000',
#   'instrument': 'https://api.robinhood.com/options/instruments/daf9bb03-1b51-4c05-96f6-a0a1c399f820/',
#   'instrument_id': 'daf9bb03-1b51-4c05-96f6-a0a1c399f820',
#   'last_trade_price': '40.480000',
#   'last_trade_size': 1,
#   'low_price': '40.310000',
#   'mark_price': '41.000000',
#   'open_interest': 23,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '42.300000',
#   'volume': 3,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00107000',
#   'chance_of_profit_long': '0.459981',
#   'chance_of_profit_short': '0.540019',
#   'delta': '0.969676',
#   'gamma': '0.002575',
#   'implied_volatility': '0.993386',
#   'rho': '0.033731',
#   'theta': '-0.088864',
#   'vega': '0.018412',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '41.520000',
#   'high_fill_rate_sell_price': '40.479000',
#   'low_fill_rate_buy_price': '40.109000',
#   'low_fill_rate_sell_price': '41.890000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.049267Z',
#   'expiration_date': '2024-11-22',
#   'id': 'da74125d-9b10-4c74-947a-0da5c45f75b5',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '147.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.994603008Z',
#   'url': 'https://api.robinhood.com/options/instruments/da74125d-9b10-4c74-947a-0da5c45f75b5/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'da74125d-9b10-4c74-947a-0da5c45f75b5_L1',
#   'short_strategy_code': 'da74125d-9b10-4c74-947a-0da5c45f75b5_S1',
#   'adjusted_mark_price': '7.300000',
#   'adjusted_mark_price_round_down': '7.300000',
#   'ask_price': '7.400000',
#   'ask_size': 10,
#   'bid_price': '7.200000',
#   'bid_size': 35,
#   'break_even_price': '154.300000',
#   'high_price': '8.580000',
#   'instrument': 'https://api.robinhood.com/options/instruments/da74125d-9b10-4c74-947a-0da5c45f75b5/',
#   'instrument_id': 'da74125d-9b10-4c74-947a-0da5c45f75b5',
#   'last_trade_price': '7.320000',
#   'last_trade_size': 1,
#   'low_price': '6.660000',
#   'mark_price': '7.300000',
#   'open_interest': 2652,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '8.230000',
#   'volume': 5211,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00147000',
#   'chance_of_profit_long': '0.334521',
#   'chance_of_profit_short': '0.665479',
#   'delta': '0.540189',
#   'gamma': '0.022782',
#   'implied_volatility': '0.649765',
#   'rho': '0.023928',
#   'theta': '-0.295877',
#   'vega': '0.106450',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '7.345000',
#   'high_fill_rate_sell_price': '7.254000',
#   'low_fill_rate_buy_price': '7.246000',
#   'low_fill_rate_sell_price': '7.353000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.051349Z',
#   'expiration_date': '2024-11-22',
#   'id': 'd05eb960-6f75-4d6a-83d6-3bca619f55bd',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '170.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.987962112Z',
#   'url': 'https://api.robinhood.com/options/instruments/d05eb960-6f75-4d6a-83d6-3bca619f55bd/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'd05eb960-6f75-4d6a-83d6-3bca619f55bd_L1',
#   'short_strategy_code': 'd05eb960-6f75-4d6a-83d6-3bca619f55bd_S1',
#   'adjusted_mark_price': '1.000000',
#   'adjusted_mark_price_round_down': '0.990000',
#   'ask_price': '1.020000',
#   'ask_size': 11,
#   'bid_price': '0.970000',
#   'bid_size': 126,
#   'break_even_price': '171.000000',
#   'high_price': '1.270000',
#   'instrument': 'https://api.robinhood.com/options/instruments/d05eb960-6f75-4d6a-83d6-3bca619f55bd/',
#   'instrument_id': 'd05eb960-6f75-4d6a-83d6-3bca619f55bd',
#   'last_trade_price': '1.000000',
#   'last_trade_size': 2,
#   'low_price': '0.830000',
#   'mark_price': '0.995000',
#   'open_interest': 9058,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '1.190000',
#   'volume': 6683,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00170000',
#   'chance_of_profit_long': '0.093198',
#   'chance_of_profit_short': '0.906802',
#   'delta': '0.124070',
#   'gamma': '0.011989',
#   'implied_volatility': '0.636801',
#   'rho': '0.005720',
#   'theta': '-0.147131',
#   'vega': '0.054921',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '1.008000',
#   'high_fill_rate_sell_price': '0.981000',
#   'low_fill_rate_buy_price': '0.984000',
#   'low_fill_rate_sell_price': '1.005000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.048631Z',
#   'expiration_date': '2024-11-22',
#   'id': 'cd1e2172-34b8-4421-aff3-b8e7cbd36a15',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '65.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.991600896Z',
#   'url': 'https://api.robinhood.com/options/instruments/cd1e2172-34b8-4421-aff3-b8e7cbd36a15/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'cd1e2172-34b8-4421-aff3-b8e7cbd36a15_L1',
#   'short_strategy_code': 'cd1e2172-34b8-4421-aff3-b8e7cbd36a15_S1',
#   'adjusted_mark_price': '82.780000',
#   'adjusted_mark_price_round_down': '82.770000',
#   'ask_price': '84.000000',
#   'ask_size': 18,
#   'bid_price': '81.550000',
#   'bid_size': 18,
#   'break_even_price': '147.780000',
#   'high_price': '82.520000',
#   'instrument': 'https://api.robinhood.com/options/instruments/cd1e2172-34b8-4421-aff3-b8e7cbd36a15/',
#   'instrument_id': 'cd1e2172-34b8-4421-aff3-b8e7cbd36a15',
#   'last_trade_price': '82.510000',
#   'last_trade_size': 1,
#   'low_price': '82.510000',
#   'mark_price': '82.775000',
#   'open_interest': 11,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '84.100000',
#   'volume': 7,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00065000',
#   'chance_of_profit_long': '0.425423',
#   'chance_of_profit_short': '0.574577',
#   'delta': '0.991368',
#   'gamma': '0.000426',
#   'implied_volatility': '2.058074',
#   'rho': '0.020976',
#   'theta': '-0.061728',
#   'vega': '0.006285',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '83.234000',
#   'high_fill_rate_sell_price': '82.315000',
#   'low_fill_rate_buy_price': '81.999000',
#   'low_fill_rate_sell_price': '83.550000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.050902Z',
#   'expiration_date': '2024-11-22',
#   'id': 'caaf92b4-16c2-4203-a8af-f18de407d85a',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '75.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.991029504Z',
#   'url': 'https://api.robinhood.com/options/instruments/caaf92b4-16c2-4203-a8af-f18de407d85a/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'caaf92b4-16c2-4203-a8af-f18de407d85a_L1',
#   'short_strategy_code': 'caaf92b4-16c2-4203-a8af-f18de407d85a_S1',
#   'adjusted_mark_price': '72.830000',
#   'adjusted_mark_price_round_down': '72.820000',
#   'ask_price': '74.050000',
#   'ask_size': 18,
#   'bid_price': '71.600000',
#   'bid_size': 18,
#   'break_even_price': '147.830000',
#   'high_price': '72.970000',
#   'instrument': 'https://api.robinhood.com/options/instruments/caaf92b4-16c2-4203-a8af-f18de407d85a/',
#   'instrument_id': 'caaf92b4-16c2-4203-a8af-f18de407d85a',
#   'last_trade_price': '72.970000',
#   'last_trade_size': 7,
#   'low_price': '72.970000',
#   'mark_price': '72.825000',
#   'open_interest': 120,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '74.080000',
#   'volume': 7,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00075000',
#   'chance_of_profit_long': '0.435185',
#   'chance_of_profit_short': '0.564815',
#   'delta': '0.988262',
#   'gamma': '0.000644',
#   'implied_volatility': '1.771525',
#   'rho': '0.024114',
#   'theta': '-0.069674',
#   'vega': '0.008218',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '73.284000',
#   'high_fill_rate_sell_price': '72.365000',
#   'low_fill_rate_buy_price': '72.049000',
#   'low_fill_rate_sell_price': '73.600000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-03T01:06:51.480946Z',
#   'expiration_date': '2024-11-22',
#   'id': 'c7461482-4f1d-4b05-a61a-cdec103d70b0',
#   'issue_date': '2024-10-03',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '123.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.980965888Z',
#   'url': 'https://api.robinhood.com/options/instruments/c7461482-4f1d-4b05-a61a-cdec103d70b0/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'c7461482-4f1d-4b05-a61a-cdec103d70b0_L1',
#   'short_strategy_code': 'c7461482-4f1d-4b05-a61a-cdec103d70b0_S1',
#   'adjusted_mark_price': '25.600000',
#   'adjusted_mark_price_round_down': '25.600000',
#   'ask_price': '26.200000',
#   'ask_size': 80,
#   'bid_price': '25.000000',
#   'bid_size': 25,
#   'break_even_price': '148.600000',
#   'high_price': '27.400000',
#   'instrument': 'https://api.robinhood.com/options/instruments/c7461482-4f1d-4b05-a61a-cdec103d70b0/',
#   'instrument_id': 'c7461482-4f1d-4b05-a61a-cdec103d70b0',
#   'last_trade_price': '25.350000',
#   'last_trade_size': 2,
#   'low_price': '24.400000',
#   'mark_price': '25.600000',
#   'open_interest': 662,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '26.650000',
#   'volume': 40,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00123000',
#   'chance_of_profit_long': '0.455162',
#   'chance_of_profit_short': '0.544838',
#   'delta': '0.911952',
#   'gamma': '0.007579',
#   'implied_volatility': '0.786260',
#   'rho': '0.036007',
#   'theta': '-0.153553',
#   'vega': '0.042847',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '25.876000',
#   'high_fill_rate_sell_price': '25.323000',
#   'low_fill_rate_buy_price': '25.283000',
#   'low_fill_rate_sell_price': '25.916000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.051605Z',
#   'expiration_date': '2024-11-22',
#   'id': 'c70af1b2-6cc0-4b4f-9673-214e191ca5df',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '149.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.996099072Z',
#   'url': 'https://api.robinhood.com/options/instruments/c70af1b2-6cc0-4b4f-9673-214e191ca5df/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'c70af1b2-6cc0-4b4f-9673-214e191ca5df_L1',
#   'short_strategy_code': 'c70af1b2-6cc0-4b4f-9673-214e191ca5df_S1',
#   'adjusted_mark_price': '6.350000',
#   'adjusted_mark_price_round_down': '6.350000',
#   'ask_price': '6.450000',
#   'ask_size': 8,
#   'bid_price': '6.250000',
#   'bid_size': 22,
#   'break_even_price': '155.350000',
#   'high_price': '7.550000',
#   'instrument': 'https://api.robinhood.com/options/instruments/c70af1b2-6cc0-4b4f-9673-214e191ca5df/',
#   'instrument_id': 'c70af1b2-6cc0-4b4f-9673-214e191ca5df',
#   'last_trade_price': '6.350000',
#   'last_trade_size': 11,
#   'low_price': '5.780000',
#   'mark_price': '6.350000',
#   'open_interest': 5249,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '7.250000',
#   'volume': 3369,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00149000',
#   'chance_of_profit_long': '0.313676',
#   'chance_of_profit_short': '0.686324',
#   'delta': '0.494540',
#   'gamma': '0.022921',
#   'implied_volatility': '0.648722',
#   'rho': '0.022017',
#   'theta': '-0.296110',
#   'vega': '0.106984',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '6.393000',
#   'high_fill_rate_sell_price': '6.306000',
#   'low_fill_rate_buy_price': '6.293000',
#   'low_fill_rate_sell_price': '6.406000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-11-08T02:06:17.310801Z',
#   'expiration_date': '2024-11-22',
#   'id': 'c5213b1d-fb12-4c58-b1b2-65b922e660f4',
#   'issue_date': '2024-11-08',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '182.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.965277952Z',
#   'url': 'https://api.robinhood.com/options/instruments/c5213b1d-fb12-4c58-b1b2-65b922e660f4/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': 'c5213b1d-fb12-4c58-b1b2-65b922e660f4_L1',
#   'short_strategy_code': 'c5213b1d-fb12-4c58-b1b2-65b922e660f4_S1',
#   'adjusted_mark_price': '0.340000',
#   'adjusted_mark_price_round_down': '0.330000',
#   'ask_price': '0.350000',
#   'ask_size': 65,
#   'bid_price': '0.320000',
#   'bid_size': 299,
#   'break_even_price': '182.840000',
#   'high_price': '0.390000',
#   'instrument': 'https://api.robinhood.com/options/instruments/c5213b1d-fb12-4c58-b1b2-65b922e660f4/',
#   'instrument_id': 'c5213b1d-fb12-4c58-b1b2-65b922e660f4',
#   'last_trade_price': '0.330000',
#   'last_trade_size': 1,
#   'low_price': '0.290000',
#   'mark_price': '0.335000',
#   'open_interest': 0,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '0.340000',
#   'volume': 113,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00182500',
#   'chance_of_profit_long': '0.035433',
# ...
#   'volume': 0,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00060000',
#   'chance_of_profit_long': '0.420481',
#   'chance_of_profit_short': '0.579519',
#   'delta': '0.992848',
#   'gamma': '0.000335',
#   'implied_volatility': '2.203211',
#   'rho': '0.019405',
#   'theta': '-0.056151',
#   'vega': '0.005327',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '88.216000',
#   'high_fill_rate_sell_price': '87.283000',
#   'low_fill_rate_buy_price': '86.956000',
#   'low_fill_rate_sell_price': '88.543000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-24T01:06:05.692164Z',
#   'expiration_date': '2024-11-22',
#   'id': '1797f24d-73b7-4c84-85a9-551b79369e2d',
#   'issue_date': '2024-10-24',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '152.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.996998656Z',
#   'url': 'https://api.robinhood.com/options/instruments/1797f24d-73b7-4c84-85a9-551b79369e2d/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': '1797f24d-73b7-4c84-85a9-551b79369e2d_L1',
#   'short_strategy_code': '1797f24d-73b7-4c84-85a9-551b79369e2d_S1',
#   'adjusted_mark_price': '4.880000',
#   'adjusted_mark_price_round_down': '4.870000',
#   'ask_price': '4.950000',
#   'ask_size': 22,
#   'bid_price': '4.800000',
#   'bid_size': 35,
#   'break_even_price': '157.380000',
#   'high_price': '5.900000',
#   'instrument': 'https://api.robinhood.com/options/instruments/1797f24d-73b7-4c84-85a9-551b79369e2d/',
#   'instrument_id': '1797f24d-73b7-4c84-85a9-551b79369e2d',
#   'last_trade_price': '4.900000',
#   'last_trade_size': 50,
#   'low_price': '4.400000',
#   'mark_price': '4.875000',
#   'open_interest': 6892,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '5.630000',
#   'volume': 3445,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00152500',
#   'chance_of_profit_long': '0.274787',
#   'chance_of_profit_short': '0.725213',
#   'delta': '0.415858',
#   'gamma': '0.022548',
#   'implied_volatility': '0.644848',
#   'rho': '0.018665',
#   'theta': '-0.286739',
#   'vega': '0.104604',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '4.911000',
#   'high_fill_rate_sell_price': '4.838000',
#   'low_fill_rate_buy_price': '4.837000',
#   'low_fill_rate_sell_price': '4.912000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.051094Z',
#   'expiration_date': '2024-11-22',
#   'id': '1487c3ee-7c43-4c23-b95f-7012b46b57f6',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '165.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.964336128Z',
#   'url': 'https://api.robinhood.com/options/instruments/1487c3ee-7c43-4c23-b95f-7012b46b57f6/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': '1487c3ee-7c43-4c23-b95f-7012b46b57f6_L1',
#   'short_strategy_code': '1487c3ee-7c43-4c23-b95f-7012b46b57f6_S1',
#   'adjusted_mark_price': '1.590000',
#   'adjusted_mark_price_round_down': '1.590000',
#   'ask_price': '1.620000',
#   'ask_size': 1,
#   'bid_price': '1.560000',
#   'bid_size': 6,
#   'break_even_price': '166.590000',
#   'high_price': '2.050000',
#   'instrument': 'https://api.robinhood.com/options/instruments/1487c3ee-7c43-4c23-b95f-7012b46b57f6/',
#   'instrument_id': '1487c3ee-7c43-4c23-b95f-7012b46b57f6',
#   'last_trade_price': '1.620000',
#   'last_trade_size': 5,
#   'low_price': '1.370000',
#   'mark_price': '1.590000',
#   'open_interest': 10988,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '1.930000',
#   'volume': 4172,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00165000',
#   'chance_of_profit_long': '0.134442',
#   'chance_of_profit_short': '0.865558',
#   'delta': '0.182111',
#   'gamma': '0.015635',
#   'implied_volatility': '0.630394',
#   'rho': '0.008355',
#   'theta': '-0.188408',
#   'vega': '0.070889',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '1.602000',
#   'high_fill_rate_sell_price': '1.577000',
#   'low_fill_rate_buy_price': '1.571000',
#   'low_fill_rate_sell_price': '1.608000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-03T01:06:51.481175Z',
#   'expiration_date': '2024-11-22',
#   'id': '0f241e3a-0c36-4ee0-a556-0095dc3b464e',
#   'issue_date': '2024-10-03',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '113.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.909770752Z',
#   'url': 'https://api.robinhood.com/options/instruments/0f241e3a-0c36-4ee0-a556-0095dc3b464e/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': '0f241e3a-0c36-4ee0-a556-0095dc3b464e_L1',
#   'short_strategy_code': '0f241e3a-0c36-4ee0-a556-0095dc3b464e_S1',
#   'adjusted_mark_price': '35.600000',
#   'adjusted_mark_price_round_down': '35.600000',
#   'ask_price': '36.450000',
#   'ask_size': 25,
#   'bid_price': '34.750000',
#   'bid_size': 25,
#   'break_even_price': '148.600000',
#   'high_price': '34.790000',
#   'instrument': 'https://api.robinhood.com/options/instruments/0f241e3a-0c36-4ee0-a556-0095dc3b464e/',
#   'instrument_id': '0f241e3a-0c36-4ee0-a556-0095dc3b464e',
#   'last_trade_price': '34.790000',
#   'last_trade_size': 1,
#   'low_price': '34.650000',
#   'mark_price': '35.600000',
#   'open_interest': 142,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '36.300000',
#   'volume': 2,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00113000',
#   'chance_of_profit_long': '0.449532',
#   'chance_of_profit_short': '0.550468',
#   'delta': '0.931590',
#   'gamma': '0.004642',
#   'implied_volatility': '1.059249',
#   'rho': '0.033658',
#   'theta': '-0.168327',
#   'vega': '0.035378',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '35.960000',
#   'high_fill_rate_sell_price': '35.239000',
#   'low_fill_rate_buy_price': '35.111000',
#   'low_fill_rate_sell_price': '36.088000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.051029Z',
#   'expiration_date': '2024-11-22',
#   'id': '07e55c0c-7ead-4814-b3b9-7e2ac99b3737',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '67.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.99148544Z',
#   'url': 'https://api.robinhood.com/options/instruments/07e55c0c-7ead-4814-b3b9-7e2ac99b3737/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': '07e55c0c-7ead-4814-b3b9-7e2ac99b3737_L1',
#   'short_strategy_code': '07e55c0c-7ead-4814-b3b9-7e2ac99b3737_S1',
#   'adjusted_mark_price': '80.750000',
#   'adjusted_mark_price_round_down': '80.750000',
#   'ask_price': '82.150000',
#   'ask_size': 25,
#   'bid_price': '79.350000',
#   'bid_size': 21,
#   'break_even_price': '147.750000',
#   'high_price': None,
#   'instrument': 'https://api.robinhood.com/options/instruments/07e55c0c-7ead-4814-b3b9-7e2ac99b3737/',
#   'instrument_id': '07e55c0c-7ead-4814-b3b9-7e2ac99b3737',
#   'last_trade_price': '71.360000',
#   'last_trade_size': 3,
#   'low_price': None,
#   'mark_price': '80.750000',
#   'open_interest': 3,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '82.100000',
#   'volume': 0,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00067000',
#   'chance_of_profit_long': '0.430070',
#   'chance_of_profit_short': '0.569930',
#   'delta': '0.992343',
#   'gamma': '0.000409',
#   'implied_volatility': '1.933500',
#   'rho': '0.021694',
#   'theta': '-0.053729',
#   'vega': '0.005656',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '81.270000',
#   'high_fill_rate_sell_price': '80.229000',
#   'low_fill_rate_buy_price': '79.858000',
#   'low_fill_rate_sell_price': '81.641000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-03T01:06:51.480988Z',
#   'expiration_date': '2024-11-22',
#   'id': '03dd5d53-bf64-48e6-bbb6-a1e97d85442f',
#   'issue_date': '2024-10-03',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '118.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.983215872Z',
#   'url': 'https://api.robinhood.com/options/instruments/03dd5d53-bf64-48e6-bbb6-a1e97d85442f/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': '03dd5d53-bf64-48e6-bbb6-a1e97d85442f_L1',
#   'short_strategy_code': '03dd5d53-bf64-48e6-bbb6-a1e97d85442f_S1',
#   'adjusted_mark_price': '30.230000',
#   'adjusted_mark_price_round_down': '30.220000',
#   'ask_price': '30.950000',
#   'ask_size': 67,
#   'bid_price': '29.500000',
#   'bid_size': 36,
#   'break_even_price': '148.230000',
#   'high_price': '30.340000',
#   'instrument': 'https://api.robinhood.com/options/instruments/03dd5d53-bf64-48e6-bbb6-a1e97d85442f/',
#   'instrument_id': '03dd5d53-bf64-48e6-bbb6-a1e97d85442f',
#   'last_trade_price': '29.900000',
#   'last_trade_size': 5,
#   'low_price': '29.740000',
#   'mark_price': '30.225000',
#   'open_interest': 345,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '31.400000',
#   'volume': 81,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00118000',
#   'chance_of_profit_long': '0.461401',
#   'chance_of_profit_short': '0.538599',
#   'delta': '0.944327',
#   'gamma': '0.005147',
#   'implied_volatility': '0.813976',
#   'rho': '0.036055',
#   'theta': '-0.115576',
#   'vega': '0.030122',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '30.558000',
#   'high_fill_rate_sell_price': '29.891000',
#   'low_fill_rate_buy_price': '29.841000',
#   'low_fill_rate_sell_price': '30.608000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.051583Z',
#   'expiration_date': '2024-11-22',
#   'id': '03bc2252-f63c-4efe-823f-8b05d9f10667',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '86.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.99019776Z',
#   'url': 'https://api.robinhood.com/options/instruments/03bc2252-f63c-4efe-823f-8b05d9f10667/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': '03bc2252-f63c-4efe-823f-8b05d9f10667_L1',
#   'short_strategy_code': '03bc2252-f63c-4efe-823f-8b05d9f10667_S1',
#   'adjusted_mark_price': '61.850000',
#   'adjusted_mark_price_round_down': '61.850000',
#   'ask_price': '63.250000',
#   'ask_size': 25,
#   'bid_price': '60.450000',
#   'bid_size': 21,
#   'break_even_price': '147.850000',
#   'high_price': None,
#   'instrument': 'https://api.robinhood.com/options/instruments/03bc2252-f63c-4efe-823f-8b05d9f10667/',
#   'instrument_id': '03bc2252-f63c-4efe-823f-8b05d9f10667',
#   'last_trade_price': '53.550000',
#   'last_trade_size': 1,
#   'low_price': None,
#   'mark_price': '61.850000',
#   'open_interest': 4,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '63.150000',
#   'volume': 0,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00086000',
#   'chance_of_profit_long': '0.446340',
#   'chance_of_profit_short': '0.553660',
#   'delta': '0.985533',
#   'gamma': '0.000942',
#   'implied_volatility': '1.449659',
#   'rho': '0.027610',
#   'theta': '-0.069846',
#   'vega': '0.009845',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '62.370000',
#   'high_fill_rate_sell_price': '61.329000',
#   'low_fill_rate_buy_price': '60.958000',
#   'low_fill_rate_sell_price': '62.741000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-03T01:06:51.481470Z',
#   'expiration_date': '2024-11-22',
#   'id': '0393414d-9613-4b4a-9f9b-5d2ba72253ea',
#   'issue_date': '2024-10-03',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '115.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.984057856Z',
#   'url': 'https://api.robinhood.com/options/instruments/0393414d-9613-4b4a-9f9b-5d2ba72253ea/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': '0393414d-9613-4b4a-9f9b-5d2ba72253ea_L1',
#   'short_strategy_code': '0393414d-9613-4b4a-9f9b-5d2ba72253ea_S1',
#   'adjusted_mark_price': '33.150000',
#   'adjusted_mark_price_round_down': '33.150000',
#   'ask_price': '33.850000',
#   'ask_size': 46,
#   'bid_price': '32.450000',
#   'bid_size': 55,
#   'break_even_price': '148.150000',
#   'high_price': '35.200000',
#   'instrument': 'https://api.robinhood.com/options/instruments/0393414d-9613-4b4a-9f9b-5d2ba72253ea/',
#   'instrument_id': '0393414d-9613-4b4a-9f9b-5d2ba72253ea',
#   'last_trade_price': '33.050000',
#   'last_trade_size': 1,
#   'low_price': '32.000000',
#   'mark_price': '33.150000',
#   'open_interest': 586,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '34.480000',
#   'volume': 113,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00115000',
#   'chance_of_profit_long': '0.461576',
#   'chance_of_profit_short': '0.538424',
#   'delta': '0.953370',
#   'gamma': '0.004226',
#   'implied_volatility': '0.860766',
#   'rho': '0.035530',
#   'theta': '-0.107076',
#   'vega': '0.026158',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '33.486000',
#   'high_fill_rate_sell_price': '32.813000',
#   'low_fill_rate_buy_price': '32.798000',
#   'low_fill_rate_sell_price': '33.501000'},
#  {'chain_id': '8d629e37-6050-47e4-906e-1c0c4de93f71',
#   'chain_symbol': 'NVDA',
#   'created_at': '2024-10-04T01:05:04.050439Z',
#   'expiration_date': '2024-11-22',
#   'id': '0022aee5-84d4-4042-80a8-28cacb821675',
#   'issue_date': '2024-10-04',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'tradable',
#   'state': 'active',
#   'strike_price': '66.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2024-11-08T20:59:59.99149568Z',
#   'url': 'https://api.robinhood.com/options/instruments/0022aee5-84d4-4042-80a8-28cacb821675/',
#   'sellout_datetime': '2024-11-22T20:30:00+00:00',
#   'long_strategy_code': '0022aee5-84d4-4042-80a8-28cacb821675_L1',
#   'short_strategy_code': '0022aee5-84d4-4042-80a8-28cacb821675_S1',
#   'adjusted_mark_price': '81.750000',
#   'adjusted_mark_price_round_down': '81.750000',
#   'ask_price': '83.150000',
#   'ask_size': 25,
#   'bid_price': '80.350000',
#   'bid_size': 21,
#   'break_even_price': '147.750000',
#   'high_price': None,
#   'instrument': 'https://api.robinhood.com/options/instruments/0022aee5-84d4-4042-80a8-28cacb821675/',
#   'instrument_id': '0022aee5-84d4-4042-80a8-28cacb821675',
#   'last_trade_price': '82.430000',
#   'last_trade_size': 1,
#   'low_price': None,
#   'mark_price': '81.750000',
#   'open_interest': 39,
#   'previous_close_date': '2024-11-07',
#   'previous_close_price': '83.080000',
#   'volume': 0,
#   'symbol': 'NVDA',
#   'occ_symbol': 'NVDA  241122C00066000',
#   'chance_of_profit_long': '0.428765',
#   'chance_of_profit_short': '0.571235',
#   'delta': '0.992416',
#   'gamma': '0.000389',
#   'implied_volatility': '1.970157',
#   'rho': '0.021367',
#   'theta': '-0.054074',
#   'vega': '0.005609',
#   'pricing_model': 'Bjerksund-Stensland 1993',
#   'high_fill_rate_buy_price': '82.270000',
#   'high_fill_rate_sell_price': '81.229000',
#   'low_fill_rate_buy_price': '80.858000',
#   'low_fill_rate_sell_price': '82.641000'}]

# %%
matchingOptions = []
for option_rh in options_rh:
    if float(option['mark_price']) > 3.73 and float(option['strike_price']) > 148:
        option = Option(self.symbol, option_rh['expiration_date'], float(option_rh['strike_price']), option_rh['type'])
        matchingOptions.append(option)    

optionTable = []
for option in matchingOptions:
    row = { 'symbol': option.symbol,
            'type': option.type,
            'exp': option.exp,
            'strike': option.strike,
            'delta': option.get_delta(),
            'theta': option.get_theta(),
            'quantity': abs(option.quantity),
            'current price': round(option.get_mark_price(), 2)
            }
    optionTable.append(row)

# %%
len(matchingOptions)
# Out:
# 0

# %%
len(options_rh)
# Out:
# 109

# %%
matchingOptions = []
for option_rh in options_rh:
    if float(option_rh['mark_price']) > 3.73 and float(option_rh['strike_price']) > 148:
        option = Option(self.symbol, option_rh['expiration_date'], float(option_rh['strike_price']), option_rh['type'])
        matchingOptions.append(option)    

optionTable = []
for option in matchingOptions:
    row = { 'symbol': option.symbol,
            'type': option.type,
            'exp': option.exp,
            'strike': option.strike,
            'delta': option.get_delta(),
            'theta': option.get_theta(),
            'quantity': abs(option.quantity),
            'current price': round(option.get_mark_price(), 2)
            }
    optionTable.append(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       2 for option_rh in options_rh:
#       3     if float(option_rh['mark_price']) > 3.73 and float(option_rh['strike_price']) > 148:
# ----> 4         option = Option(self.symbol, option_rh['expiration_date'], float(option_rh['strike_price']), option_rh['type'])
#       5         matchingOptions.append(option)
#       7 optionTable = []
#
# NameError: name 'self' is not defined

# %%
matchingOptions = []
for option_rh in options_rh:
    if float(option_rh['mark_price']) > 3.73 and float(option_rh['strike_price']) > 148:
        option = Option('NVDA', option_rh['expiration_date'], float(option_rh['strike_price']), option_rh['type'])
        matchingOptions.append(option)    

optionTable = []
for option in matchingOptions:
    row = { 'symbol': option.symbol,
            'type': option.type,
            'exp': option.exp,
            'strike': option.strike,
            'delta': option.get_delta(),
            'theta': option.get_theta(),
            'quantity': abs(option.quantity),
            'current price': round(option.get_mark_price(), 2)
            }
    optionTable.append(row)
# Out:
# [2024-11-10 11:43:29,869] {jh_options.py:33} INFO - updating option...
# Loading Market Data \
# [2024-11-10 11:43:30,644] {jh_options.py:33} INFO - updating option...
# Loading Market Data |
# [2024-11-10 11:43:31,177] {jh_options.py:33} INFO - updating option...
# Loading Market Data /
# [2024-11-10 11:43:31,721] {jh_options.py:33} INFO - updating option...
# Loading Market Data

# %%
len(matchingOptions)
# Out:
# 4

# %%
optionTable
# Out:
# [{'symbol': 'NVDA',
#   'type': 'call',
#   'exp': '2024-11-22',
#   'strike': 149.0,
#   'delta': 0.4945,
#   'theta': -0.2964,
#   'quantity': 0,
#   'current price': 6.35},
#  {'symbol': 'NVDA',
#   'type': 'call',
#   'exp': '2024-11-22',
#   'strike': 155.0,
#   'delta': 0.3622,
#   'theta': -0.2745,
#   'quantity': 0,
#   'current price': 4.0},
#  {'symbol': 'NVDA',
#   'type': 'call',
#   'exp': '2024-11-22',
#   'strike': 150.0,
#   'delta': 0.4721,
#   'theta': -0.296,
#   'quantity': 0,
#   'current price': 5.92},
#  {'symbol': 'NVDA',
#   'type': 'call',
#   'exp': '2024-11-22',
#   'strike': 152.5,
#   'delta': 0.4158,
#   'theta': -0.287,
#   'quantity': 0,
#   'current price': 4.88}]

# %%
matchingOptions = []
for option_rh in options_rh:
    if float(option_rh['mark_price']) > 3.73 and float(option_rh['strike_price']) > 148:
        option = Option('NVDA', option_rh['expiration_date'], float(option_rh['strike_price']), option_rh['type'])
        matchingOptions.append(option)    

optionTable = []
for option in matchingOptions:
    row = { 'symbol': option.symbol,
            'type': option.type,
            'exp': option.exp,
            'strike': option.strike,
            'delta': option.get_delta(),
            'theta': option.get_theta(),
            'quantity': abs(option.quantity),
            'current price': round(option.get_mark_price(), 2)
            }
    optionTable.append(row)
df = pd.DataFrame(optionTable)
# Out:
# [2024-11-10 11:44:13,855] {jh_options.py:33} INFO - updating option...
# Loading Market Data \
# [2024-11-10 11:44:14,538] {jh_options.py:33} INFO - updating option...
# Loading Market Data |
# [2024-11-10 11:44:15,084] {jh_options.py:33} INFO - updating option...
# Loading Market Data /
# [2024-11-10 11:44:15,644] {jh_options.py:33} INFO - updating option...
# Loading Market Data

# %%
df
# Out:
#   symbol  type         exp  strike   delta   theta  quantity  current price
# 0   NVDA  call  2024-11-22   149.0  0.4945 -0.2965         0           6.35
# 1   NVDA  call  2024-11-22   155.0  0.3622 -0.2745         0           4.00
# 2   NVDA  call  2024-11-22   150.0  0.4721 -0.2960         0           5.92
# 3   NVDA  call  2024-11-22   152.5  0.4158 -0.2870         0           4.88

# %%
matchingOptions = []
for option_rh in options_rh:
    if float(option_rh['mark_price']) > 3.73 and float(option_rh['strike_price']) > 148:
        option = Option('NVDA', option_rh['expiration_date'], float(option_rh['strike_price']), option_rh['type'])
        matchingOptions.append(option)    
matchingOptions = sorted(matchingOptions, key=lambda x: x.strike())

optionTable = []
for option in matchingOptions:
    row = { 'symbol': option.symbol,
            'type': option.type,
            'exp': option.exp,
            'strike': option.strike,
            'delta': option.get_delta(),
            'theta': option.get_theta(),
            'quantity': abs(option.quantity),
            'current price': round(option.get_mark_price(), 2)
            }
    optionTable.append(row)
df = pd.DataFrame(optionTable)
# Out:
# [2024-11-10 11:47:26,898] {jh_options.py:33} INFO - updating option...
# Loading Market Data \
# [2024-11-10 11:47:27,439] {jh_options.py:33} INFO - updating option...
# Loading Market Data |
# [2024-11-10 11:47:28,130] {jh_options.py:33} INFO - updating option...
# Loading Market Data /
# [2024-11-10 11:47:29,221] {jh_options.py:33} INFO - updating option...
# Loading Market Data
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 6
#       4         option = Option('NVDA', option_rh['expiration_date'], float(option_rh['strike_price']), option_rh['type'])
#       5         matchingOptions.append(option)
# ----> 6 matchingOptions = sorted(matchingOptions, key=lambda x: x.strike())
#       8 optionTable = []
#       9 for option in matchingOptions:
#
# Cell In[34], line 6, in <lambda>(x)
#       4         option = Option('NVDA', option_rh['expiration_date'], float(option_rh['strike_price']), option_rh['type'])
#       5         matchingOptions.append(option)
# ----> 6 matchingOptions = sorted(matchingOptions, key=lambda x: x.strike())
#       8 optionTable = []
#       9 for option in matchingOptions:
#
# TypeError: 'float' object is not callable
